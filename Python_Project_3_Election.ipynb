# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import calendar
import glob


pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 25)
pd.set_option('display.width', 25)

# %% [markdown]
# #### Browsing .csv files

# %%
path = "D:\My commercial projects\Python\Project 3"

filenames = glob.glob(path + "\*.csv")
print('Filenames:', filenames,sep='\n' )

for file in filenames:
        print("Reading .csv files= ", file)
        print(pd.read_csv(file))
# Out:
# Filenames:
# []

# %% [markdown]
# ##### Open .csv files by pandas

# %%
dfResultElectionList = pd.read_csv('D:\My commercial projects\Python\Project 3\Python_Project_3_World_Election\election_list results.csv')
dfLeaderList  = pd.read_csv('D:\My commercial projects\Python\Project 3\Python_Project_3_World_Election\leaders list in both regime and democratic govt.csv')
dfGovernment  = pd.read_csv(r"D:\My commercial projects\Python\Project 3\Python_Project_3_World_Election\regime government.csv")

# %% [markdown]
# ##### Exploratory Data Analysis: dfResultElectionList

# %%
dfResultElectionList
# Out:
#       ccode  \
# 0       700
# 1       700
# 2       700
# 3       700
# 4       700
# ...     ...
# 4363    552
# 4364    552
# 4365    552
# 4366    552
# 4367    552
#
#       election number  \
# 0                   1
# 1                   1
# 2                   2
# 3                   3
# 4                   3
# ...               ...
# 4363               12
# 4364               13
# 4365               13
# 4366               14
# 4367               15
#
#           country  \
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 4363     Zimbabwe
# 4364     Zimbabwe
# 4365     Zimbabwe
# 4366     Zimbabwe
# 4367     Zimbabwe
#
#       election year  \
# 0              1987
# 1              1988
# 2              2004
# 3              2004
# 4              2004
# ...             ...
# 4363           2008
# 4364           2008
# 4365           2008
# 4366           2013
# 4367           2018
#
#       election month   \
# 0                  11
# 1                   4
# 2                   7
# 3                   7
# 4                  10
# ...               ...
# 4363                3
# 4364                3
# 4365                6
# 4366                7
# 4367                7
#
#      election day  \
# 0
# 1               6
# 2
# 3
# 4               9
# ...           ...
# 4363           29
# 4364           29
# 4365           27
# 4366           31
# 4367           30
#
#       sequence  \
# 0            1
# 1            2
# 2            1
# 3            1
# 4            2
# ...        ...
# 4363         1
# 4364         1
# 4365         2
# 4366         1
# 4367         1
#
#                    event  \
# 0              Announced
# 1            Vote, Early
# 2       Deadline Not Met
# 3              Announced
# 4            Vote, Early
# ...                  ...
# 4363  Vote, As Scheduled
# 4364           Announced
# 4365         Vote, Early
# 4366  Vote, As Scheduled
# 4367  Vote, As Scheduled
#
#       election number.1  \
# 0                700001
# 1                700001
# 2                700002
# 3                700003
# 4                700003
# ...                 ...
# 4363             552012
# 4364             552013
# 4365             552013
# 4366             552014
# 4367             552015
#
#      type direct  \
# 0       L      Y
# 1       L      Y
# 2       X      Y
# 3       X      Y
# 4       X      Y
# ...   ...    ...
# 4363    X      Y
# 4364    X      Y
# 4365    X      Y
# 4366    X      Y
# 4367    X      Y
#
#      regular victory  \
# 0          N       Y
# 1          N       Y
# 2          N     NaN
# 3          N       Y
# 4          N       Y
# ...      ...     ...
# 4363       Y     NaN
# 4364       Y       Y
# 4365       Y       Y
# 4366       Y       Y
# 4367       Y       Y
#
#      change runoff
# 0         N      N
# 1         N      N
# 2       NaN      N
# 3         N      N
# 4         N      N
# ...     ...    ...
# 4363    NaN      1
# 4364      N      2
# 4365      N      2
# 4366      N      N
# 4367      N      N
#
# [4368 rows x 15 columns]

# %% [markdown]
# ##### Rename the name of columns

# %%
list(dfResultElectionList)
# Out:
# ['ccode',
#  'election number',
#  'country',
#  'election year',
#  'election month ',
#  'election day',
#  'sequence',
#  'event',
#  'election number.1',
#  'type',
#  'direct',
#  'regular',
#  'victory',
#  'change',
#  'runoff']

# %%
dfResultElectionList.rename(columns = {'election number': 'Election Number',
                                       'country':'Country',
                                        'election year':'Election Year',
                                        'election month ':'Election Month',
                                        'election day':'Election Day',
                                        'sequence':'Sequence',
                                        'event':'Event',
                                        'election number.1':'Election Number',
                                        'type':'Type',
                                        'direct':'Direct',
                                        'regular':'Regular',
                                        'victory':'Victory',
                                        'change':'Change',
                                        'runoff':'Runoff Election'}, inplace=True)

# %%
list(dfResultElectionList)
# Out:
# ['ccode',
#  'Election Number',
#  'Country',
#  'Election Year',
#  'Election Month',
#  'Election Day',
#  'Sequence',
#  'Event',
#  'Election Number',
#  'Type',
#  'Direct',
#  'Regular',
#  'Victory',
#  'Change',
#  'Runoff Election']

# %% [markdown]
# ##### Look for NaN values

# %%
dfResultElectionList.isnull().sum()
# Out:
# ccode                0
# Election Number      0
# Country              0
# Election Year        0
# Election Month       0
# Election Day         3
# Sequence             0
# Event                0
# Election Number      0
# Type                 2
# Direct               0
# Regular              3
# Victory            691
# Change             690
# Runoff Election     20
# dtype: int64

# %% [markdown]
# ##### The percentage of missing values in each column

# %%
round((dfResultElectionList.isnull().sum()/(len(dfResultElectionList)))*100,2)
# Out:
# ccode               0.00
# Election Number     0.00
# Country             0.00
# Election Year       0.00
# Election Month      0.00
# Election Day        0.07
# Sequence            0.00
# Event               0.00
# Election Number     0.00
# Type                0.05
# Direct              0.00
# Regular             0.07
# Victory            15.82
# Change             15.80
# Runoff Election     0.46
# dtype: float64

# %% [markdown]
# ##### The analysis of NaN values

# %%
dfResultElectionList[dfResultElectionList.isnull().any(axis=1)]
# Out:
#       ccode  \
# 2       700
# 6       700
# 9       700
# 10      700
# 11      700
# ...     ...
# 4317    101
# 4325    679
# 4326    679
# 4345    620
# 4363    552
#
#       Election Number  \
# 2                   2
# 6                   5
# 9                   7
# 10                  7
# 11                  8
# ...               ...
# 4317               23
# 4325                7
# 4326                8
# 4345                6
# 4363               12
#
#           Country  \
# 2     Afghanistan
# 6     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# ...           ...
# 4317    Venezuela
# 4325        Yemen
# 4326        Yemen
# 4345        Libya
# 4363     Zimbabwe
#
#       Election Year  \
# 2              2004
# 6              2014
# 9              2018
# 10             2019
# 11             2019
# ...             ...
# 4317           2024
# 4325           2014
# 4326           2015
# 4345           2021
# 4363           2008
#
#       Election Month  \
# 2                  7
# 6                  4
# 9                 12
# 10                 4
# 11                 3
# ...              ...
# 4317               5
# 4325               2
# 4326               2
# 4345              12
# 4363               3
#
#      Election Day  \
# 2
# 6               5
# 9              26
# 10             20
# 11             20
# ...           ...
# 4317
# 4325
# 4326
# 4345           24
# 4363           29
#
#       Sequence  \
# 2            1
# 6            1
# 9            1
# 10           2
# 11           1
# ...        ...
# 4317         1
# 4325         1
# 4326         1
# 4345         1
# 4363         1
#
#                     Event  \
# 2        Deadline Not Met
# 6      Vote, As Scheduled
# 9         Delay Announced
# 10                 Voided
# 11        Delay Announced
# ...                   ...
# 4317   Upcoming, Deadline
# 4325     Deadline Not Met
# 4326     Deadline Not Met
# 4345  Upcoming, Scheduled
# 4363   Vote, As Scheduled
#
#       Election Number  \
# 2              700002
# 6              700005
# 9              700007
# 10             700007
# 11             700008
# ...               ...
# 4317           101023
# 4325           679007
# 4326           679008
# 4345           620006
# 4363           552012
#
#      Type Direct  \
# 2       X      Y
# 6       X      Y
# 9       X      Y
# 10      X      Y
# 11      X      Y
# ...   ...    ...
# 4317    X      Y
# 4325    X      Y
# 4326    X      Y
# 4345    L      Y
# 4363    X      Y
#
#      Regular Victory  \
# 2          N     NaN
# 6          Y     NaN
# 9          Y     NaN
# 10         Y     NaN
# 11         Y     NaN
# ...      ...     ...
# 4317       Y     NaN
# 4325       N     NaN
# 4326       N     NaN
# 4345       N     NaN
# 4363       Y     NaN
#
#      Change  \
# 2       NaN
# 6       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# ...     ...
# 4317    NaN
# 4325    NaN
# 4326    NaN
# 4345    NaN
# 4363    NaN
#
#      Runoff Election
# 2                  N
# 6                  1
# 9                  N
# 10                 N
# 11                 N
# ...              ...
# 4317               N
# 4325               N
# 4326               N
# 4345               N
# 4363               1
#
# [694 rows x 15 columns]

# %%
dfResultElectionList[dfResultElectionList['Change'].isna()]
# Out:
#       ccode  \
# 2       700
# 6       700
# 9       700
# 10      700
# 11      700
# ...     ...
# 4317    101
# 4325    679
# 4326    679
# 4345    620
# 4363    552
#
#       Election Number  \
# 2                   2
# 6                   5
# 9                   7
# 10                  7
# 11                  8
# ...               ...
# 4317               23
# 4325                7
# 4326                8
# 4345                6
# 4363               12
#
#           Country  \
# 2     Afghanistan
# 6     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# ...           ...
# 4317    Venezuela
# 4325        Yemen
# 4326        Yemen
# 4345        Libya
# 4363     Zimbabwe
#
#       Election Year  \
# 2              2004
# 6              2014
# 9              2018
# 10             2019
# 11             2019
# ...             ...
# 4317           2024
# 4325           2014
# 4326           2015
# 4345           2021
# 4363           2008
#
#       Election Month  \
# 2                  7
# 6                  4
# 9                 12
# 10                 4
# 11                 3
# ...              ...
# 4317               5
# 4325               2
# 4326               2
# 4345              12
# 4363               3
#
#      Election Day  \
# 2
# 6               5
# 9              26
# 10             20
# 11             20
# ...           ...
# 4317
# 4325
# 4326
# 4345           24
# 4363           29
#
#       Sequence  \
# 2            1
# 6            1
# 9            1
# 10           2
# 11           1
# ...        ...
# 4317         1
# 4325         1
# 4326         1
# 4345         1
# 4363         1
#
#                     Event  \
# 2        Deadline Not Met
# 6      Vote, As Scheduled
# 9         Delay Announced
# 10                 Voided
# 11        Delay Announced
# ...                   ...
# 4317   Upcoming, Deadline
# 4325     Deadline Not Met
# 4326     Deadline Not Met
# 4345  Upcoming, Scheduled
# 4363   Vote, As Scheduled
#
#       Election Number  \
# 2              700002
# 6              700005
# 9              700007
# 10             700007
# 11             700008
# ...               ...
# 4317           101023
# 4325           679007
# 4326           679008
# 4345           620006
# 4363           552012
#
#      Type Direct  \
# 2       X      Y
# 6       X      Y
# 9       X      Y
# 10      X      Y
# 11      X      Y
# ...   ...    ...
# 4317    X      Y
# 4325    X      Y
# 4326    X      Y
# 4345    L      Y
# 4363    X      Y
#
#      Regular Victory  \
# 2          N     NaN
# 6          Y     NaN
# 9          Y     NaN
# 10         Y     NaN
# 11         Y     NaN
# ...      ...     ...
# 4317       Y     NaN
# 4325       N     NaN
# 4326       N     NaN
# 4345       N     NaN
# 4363       Y     NaN
#
#      Change  \
# 2       NaN
# 6       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# ...     ...
# 4317    NaN
# 4325    NaN
# 4326    NaN
# 4345    NaN
# 4363    NaN
#
#      Runoff Election
# 2                  N
# 6                  1
# 9                  N
# 10                 N
# 11                 N
# ...              ...
# 4317               N
# 4325               N
# 4326               N
# 4345               N
# 4363               1
#
# [690 rows x 15 columns]

# %%
dfResultElectionList[dfResultElectionList['Runoff Election'].isna()]
# Out:
#       ccode  \
# 331      53
# 725     482
# 726     482
# 800     710
# 831     100
# 1288    651
# 1447    220
# 1629     55
# 1630     55
# 1631     55
# 2518    781
# 2551    432
# 2796    970
# 2797    970
# 2863    255
# 3565    940
# 4099    701
# 4151    369
# 4152    369
# 4162    369
#
#       Election Number  \
# 331                12
# 725                14
# 726                14
# 800                12
# 831                23
# 1288               24
# 1447               29
# 1629                9
# 1630                9
# 1631                9
# 2518                3
# 2551               13
# 2796               22
# 2797               22
# 2863                9
# 3565               11
# 4099                5
# 4151                9
# 4152                9
# 4162               16
#
#                        Country  \
# 331                   Barbados
# 725   Central African Republic
# 726   Central African Republic
# 800                      China
# 831                   Colombia
# 1288                     Egypt
# 1447                    France
# 1629                   Grenada
# 1630                   Grenada
# 1631                   Grenada
# 2518                  Maldives
# 2551                      Mali
# 2796                     Nauru
# 2797                     Nauru
# 2863                   Germany
# 3565           Solomon Islands
# 4099              Turkmenistan
# 4151                   Ukraine
# 4152                   Ukraine
# 4162                   Ukraine
#
#       Election Year  \
# 331            2023
# 725            2010
# 726            2010
# 800            2022
# 831            2022
# 1288           2019
# 1447           2022
# 1629           2016
# 1630           2016
# 1631           2016
# 2518           1972
# 2551           2007
# 2796           2013
# 2797           2013
# 2863           2021
# 3565           2024
# 4099           2022
# 4151           2004
# 4152           2004
# 4162           2024
#
#       Election Month  \
# 331                5
# 725                3
# 726                5
# 800               10
# 831                5
# 1288               4
# 1447               4
# 1629               9
# 1630              10
# 1631              10
# 2518               9
# 2551               4
# 2796               3
# 2797               4
# 2863               9
# 3565               4
# 4099               2
# 4151              10
# 4152              11
# 4162               5
#
#      Election Day  \
# 331
# 725            30
# 726
# 800
# 831             1
# 1288           22
# 1447
# 1629           23
# 1630           21
# 1631           24
# 2518
# 2551           29
# 2796            1
# 2797            6
# 2863           26
# 3565
# 4099           12
# 4151           31
# 4152           21
# 4162
#
#       Sequence  \
# 331          1
# 725          1
# 726          2
# 800          1
# 831          1
# 1288         2
# 1447         1
# 1629         1
# 1630         2
# 1631         3
# 2518         1
# 2551         1
# 2796         1
# 2797         2
# 2863         1
# 3565         1
# 4099         1
# 4151         1
# 4152         2
# 4162         1
#
#                     Event  \
# 331   Upcoming, Scheduled
# 725             Announced
# 726      Deadline Not Met
# 800   Upcoming, Scheduled
# 831   Upcoming, Scheduled
# 1288   Vote, As Scheduled
# 1447  Upcoming, Scheduled
# 1629            Announced
# 1630      Delay Announced
# 1631     Deadline Not Met
# 2518     Deadline Not Met
# 2551   Vote, As Scheduled
# 2796            Announced
# 2797     Deadline Not Met
# 2863   Upcoming, Deadline
# 3565   Upcoming, Deadline
# 4099  Upcoming, Scheduled
# 4151            Announced
# 4152               Voided
# 4162  Upcoming, Scheduled
#
#       Election Number  \
# 331             53012
# 725            482014
# 726            482014
# 800            710012
# 831            100023
# 1288           651024
# 1447           220029
# 1629            55009
# 1630            55009
# 1631            55009
# 2518           781003
# 2551           432013
# 2796           970022
# 2797           970022
# 2863           255009
# 3565           940011
# 4099           701005
# 4151           369009
# 4152           369009
# 4162           369016
#
#      Type Direct  \
# 331     L      Y
# 725     X      Y
# 726     X      Y
# 800     X      N
# 831     X      Y
# 1288    R      Y
# 1447    X      Y
# 1629    R      Y
# 1630    R      Y
# 1631    R      Y
# 2518    X      Y
# 2551    X      Y
# 2796    L      Y
# 2797    L      Y
# 2863    L      Y
# 3565    L      Y
# 4099    X      Y
# 4151    X      Y
# 4152    X      Y
# 4162    X      Y
#
#      Regular Victory  \
# 331        Y     NaN
# 725        Y     NaN
# 726        Y     NaN
# 800        Y     NaN
# 831        Y     NaN
# 1288       N       Y
# 1447       Y     NaN
# 1629       N     NaN
# 1630       N     NaN
# 1631       N     NaN
# 2518       Y     NaN
# 2551       Y       Y
# 2796       Y     NaN
# 2797       Y     NaN
# 2863       Y     NaN
# 3565       Y     NaN
# 4099       Y     NaN
# 4151       Y     NaN
# 4152       Y     NaN
# 4162       Y     NaN
#
#      Change  \
# 331     NaN
# 725     NaN
# 726     NaN
# 800     NaN
# 831     NaN
# 1288      N
# 1447    NaN
# 1629    NaN
# 1630    NaN
# 1631    NaN
# 2518    NaN
# 2551      N
# 2796    NaN
# 2797    NaN
# 2863    NaN
# 3565    NaN
# 4099    NaN
# 4151    NaN
# 4152    NaN
# 4162    NaN
#
#      Runoff Election
# 331              NaN
# 725              NaN
# 726              NaN
# 800              NaN
# 831              NaN
# 1288             NaN
# 1447             NaN
# 1629             NaN
# 1630             NaN
# 1631             NaN
# 2518             NaN
# 2551             NaN
# 2796             NaN
# 2797             NaN
# 2863             NaN
# 3565             NaN
# 4099             NaN
# 4151             NaN
# 4152             NaN
# 4162             NaN

# %% [markdown]
# ##### Changing NaN values and blank space to either 1 or Not Available

# %%
dfResultElectionList['Election Day'] = dfResultElectionList['Election Day'].fillna(1)
dfResultElectionList['Election Day'] = dfResultElectionList['Election Day'].replace(' ',1,regex=True)
dfResultElectionList['Type'] = dfResultElectionList['Type'].fillna("Not Available")
dfResultElectionList['Regular'] = dfResultElectionList['Regular'].fillna("Not Available")
dfResultElectionList['Victory'] = dfResultElectionList['Victory'].fillna("Not Available")
dfResultElectionList['Change'] = dfResultElectionList['Change'].fillna("Not Available")
dfResultElectionList['Runoff Election'] = dfResultElectionList['Runoff Election'].fillna("Not Available")

# %%
dfResultElectionList.isnull().sum()
# Out:
# ccode              0
# Election Number    0
# Country            0
# Election Year      0
# Election Month     0
# Election Day       0
# Sequence           0
# Event              0
# Election Number    0
# Type               0
# Direct             0
# Regular            0
# Victory            0
# Change             0
# Runoff Election    0
# dtype: int64

# %%
dfResultElectionList
# Out:
#       ccode  \
# 0       700
# 1       700
# 2       700
# 3       700
# 4       700
# ...     ...
# 4363    552
# 4364    552
# 4365    552
# 4366    552
# 4367    552
#
#       Election Number  \
# 0                   1
# 1                   1
# 2                   2
# 3                   3
# 4                   3
# ...               ...
# 4363               12
# 4364               13
# 4365               13
# 4366               14
# 4367               15
#
#           Country  \
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 4363     Zimbabwe
# 4364     Zimbabwe
# 4365     Zimbabwe
# 4366     Zimbabwe
# 4367     Zimbabwe
#
#       Election Year  \
# 0              1987
# 1              1988
# 2              2004
# 3              2004
# 4              2004
# ...             ...
# 4363           2008
# 4364           2008
# 4365           2008
# 4366           2013
# 4367           2018
#
#       Election Month  \
# 0                 11
# 1                  4
# 2                  7
# 3                  7
# 4                 10
# ...              ...
# 4363               3
# 4364               3
# 4365               6
# 4366               7
# 4367               7
#
#      Election Day  \
# 0               1
# 1               6
# 2               1
# 3               1
# 4               9
# ...           ...
# 4363           29
# 4364           29
# 4365           27
# 4366           31
# 4367           30
#
#       Sequence  \
# 0            1
# 1            2
# 2            1
# 3            1
# 4            2
# ...        ...
# 4363         1
# 4364         1
# 4365         2
# 4366         1
# 4367         1
#
#                    Event  \
# 0              Announced
# 1            Vote, Early
# 2       Deadline Not Met
# 3              Announced
# 4            Vote, Early
# ...                  ...
# 4363  Vote, As Scheduled
# 4364           Announced
# 4365         Vote, Early
# 4366  Vote, As Scheduled
# 4367  Vote, As Scheduled
#
#       Election Number  \
# 0              700001
# 1              700001
# 2              700002
# 3              700003
# 4              700003
# ...               ...
# 4363           552012
# 4364           552013
# 4365           552013
# 4366           552014
# 4367           552015
#
#      Type Direct  \
# 0       L      Y
# 1       L      Y
# 2       X      Y
# 3       X      Y
# 4       X      Y
# ...   ...    ...
# 4363    X      Y
# 4364    X      Y
# 4365    X      Y
# 4366    X      Y
# 4367    X      Y
#
#      Regular  \
# 0          N
# 1          N
# 2          N
# 3          N
# 4          N
# ...      ...
# 4363       Y
# 4364       Y
# 4365       Y
# 4366       Y
# 4367       Y
#
#             Victory  \
# 0                 Y
# 1                 Y
# 2     Not Available
# 3                 Y
# 4                 Y
# ...             ...
# 4363  Not Available
# 4364              Y
# 4365              Y
# 4366              Y
# 4367              Y
#
#              Change  \
# 0                 N
# 1                 N
# 2     Not Available
# 3                 N
# 4                 N
# ...             ...
# 4363  Not Available
# 4364              N
# 4365              N
# 4366              N
# 4367              N
#
#      Runoff Election
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 4363               1
# 4364               2
# 4365               2
# 4366               N
# 4367               N
#
# [4368 rows x 15 columns]

# %% [markdown]
# ##### Looking for duplicates

# %%
dfResultElectionList.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Customising data types of columns, then creating a date column from columns

# %%
dfResultElectionList.dtypes
# Out:
# ccode               int64
# Election Number     int64
# Country            object
# Election Year       int64
# Election Month      int64
# Election Day       object
# Sequence            int64
# Event              object
# Election Number     int64
# Type               object
# Direct             object
# Regular            object
# Victory            object
# Change             object
# Runoff Election    object
# dtype: object

# %%
dfResultElectionList.astype({'Election Day': 'int64'}).dtypes
# Out:
# ccode               int64
# Election Number     int64
# Country            object
# Election Year       int64
# Election Month      int64
# Election Day        int64
# Sequence            int64
# Event              object
# Election Number     int64
# Type               object
# Direct             object
# Regular            object
# Victory            object
# Change             object
# Runoff Election    object
# dtype: object

# %%
dfResultElectionList.rename(columns = {'Election Year':'year', 'Election Month':'month', 'Election Day':'day'}, inplace=True)
dfResultElectionList['Date of Election'] = pd.to_datetime(dfResultElectionList[['year',
                                                                                'month',
                                                                                 'day']],
                                                          errors='coerce')

# %%
dfResultElectionList.rename(columns = {'year':'Election Year',
                                       'month':'Election Month', 
                                       'day':'Election Day'},
                                        inplace=True)

# %%
seventh_columns = dfResultElectionList.pop('Date of Election')
dfResultElectionList.insert(6,'Date of Election',seventh_columns)

# %%
dfResultElectionList
# Out:
#       ccode  \
# 0       700
# 1       700
# 2       700
# 3       700
# 4       700
# ...     ...
# 4363    552
# 4364    552
# 4365    552
# 4366    552
# 4367    552
#
#       Election Number  \
# 0                   1
# 1                   1
# 2                   2
# 3                   3
# 4                   3
# ...               ...
# 4363               12
# 4364               13
# 4365               13
# 4366               14
# 4367               15
#
#           Country  \
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 4363     Zimbabwe
# 4364     Zimbabwe
# 4365     Zimbabwe
# 4366     Zimbabwe
# 4367     Zimbabwe
#
#       Election Year  \
# 0              1987
# 1              1988
# 2              2004
# 3              2004
# 4              2004
# ...             ...
# 4363           2008
# 4364           2008
# 4365           2008
# 4366           2013
# 4367           2018
#
#       Election Month  \
# 0                 11
# 1                  4
# 2                  7
# 3                  7
# 4                 10
# ...              ...
# 4363               3
# 4364               3
# 4365               6
# 4366               7
# 4367               7
#
#      Election Day  \
# 0               1
# 1               6
# 2               1
# 3               1
# 4               9
# ...           ...
# 4363           29
# 4364           29
# 4365           27
# 4366           31
# 4367           30
#
#      Date of Election  \
# 0          1987-11-01
# 1          1988-04-06
# 2          2004-07-01
# 3          2004-07-01
# 4          2004-10-09
# ...               ...
# 4363       2008-03-29
# 4364       2008-03-29
# 4365       2008-06-27
# 4366       2013-07-31
# 4367       2018-07-30
#
#       Sequence  \
# 0            1
# 1            2
# 2            1
# 3            1
# 4            2
# ...        ...
# 4363         1
# 4364         1
# 4365         2
# 4366         1
# 4367         1
#
#                    Event  \
# 0              Announced
# 1            Vote, Early
# 2       Deadline Not Met
# 3              Announced
# 4            Vote, Early
# ...                  ...
# 4363  Vote, As Scheduled
# 4364           Announced
# 4365         Vote, Early
# 4366  Vote, As Scheduled
# 4367  Vote, As Scheduled
#
#       Election Number  \
# 0              700001
# 1              700001
# 2              700002
# 3              700003
# 4              700003
# ...               ...
# 4363           552012
# 4364           552013
# 4365           552013
# 4366           552014
# 4367           552015
#
#      Type Direct  \
# 0       L      Y
# 1       L      Y
# 2       X      Y
# 3       X      Y
# 4       X      Y
# ...   ...    ...
# 4363    X      Y
# 4364    X      Y
# 4365    X      Y
# 4366    X      Y
# 4367    X      Y
#
#      Regular  \
# 0          N
# 1          N
# 2          N
# 3          N
# 4          N
# ...      ...
# 4363       Y
# 4364       Y
# 4365       Y
# 4366       Y
# 4367       Y
#
#             Victory  \
# 0                 Y
# 1                 Y
# 2     Not Available
# 3                 Y
# 4                 Y
# ...             ...
# 4363  Not Available
# 4364              Y
# 4365              Y
# 4366              Y
# 4367              Y
#
#              Change  \
# 0                 N
# 1                 N
# 2     Not Available
# 3                 N
# 4                 N
# ...             ...
# 4363  Not Available
# 4364              N
# 4365              N
# 4366              N
# 4367              N
#
#      Runoff Election
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 4363               1
# 4364               2
# 4365               2
# 4366               N
# 4367               N
#
# [4368 rows x 16 columns]

# %%
dfResultElectionList.astype({'Election Day':'int64'}).dtypes
# Out:
# ccode                        int64
# Election Number              int64
# Country                     object
# Election Year                int64
# Election Month               int64
# Election Day                 int64
# Date of Election    datetime64[ns]
# Sequence                     int64
# Event                       object
# Election Number              int64
# Type                        object
# Direct                      object
# Regular                     object
# Victory                     object
# Change                      object
# Runoff Election             object
# dtype: object

# %% [markdown]
# ##### General information after cleaning:

# %%
dfResultElectionList.info(), dfResultElectionList.size, dfResultElectionList.shape, dfResultElectionList.dtypes.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4368 entries, 0 to 4367
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ccode             4368 non-null   int64
#  1   Election Number   4368 non-null   int64
#  2   Country           4368 non-null   object
#  3   Election Year     4368 non-null   int64
#  4   Election Month    4368 non-null   int64
#  5   Election Day      4368 non-null   object
#  6   Date of Election  4367 non-null   datetime64[ns]
#  7   Sequence          4368 non-null   int64
#  8   Event             4368 non-null   object
#  9   Election Number   4368 non-null   int64
#  10  Type              4368 non-null   object
#  11  Direct            4368 non-null   object
#  12  Regular           4368 non-null   object
#  13  Victory           4368 non-null   object
#  14  Change            4368 non-null   object
#  15  Runoff Election   4368 non-null   object
# dtypes: datetime64[ns](1), int64(6), object(9)
# memory usage: 546.1+ KB
# (None,
#  69888,
#  (4368, 16),
#  object            9
#  int64             6
#  datetime64[ns]    1
#  dtype: int64)

# %% [markdown]
# ##### Exploratory Data Analysis: dfLeaderList

# %%
dfLeaderList
# Out:
#      stateabb  ccode  \
# 0         USA      2
# 1         USA      2
# 2         USA      2
# 3         USA      2
# 4         USA      2
# ...       ...    ...
# 2539      WSM    990
# 2540      WSM    990
# 2541      WSM    990
# 2542      WSM    990
# 2543      WSM    990
#
#         leadid  \
# 0      A2.9-46
# 1      A2.9-49
# 2      A2.9-52
# 3      A2.9-55
# 4      A2.9-58
# ...        ...
# 2539  kb-800-8
# 2540  kb-800-9
# 2541  kb-810-1
# 2542  kb-810-2
# 2543  mf-990-1
#
#                             leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       sdate  smonth  \
# 0        12       4
# 1        20       1
# 2        20       1
# 3        22      11
# 4        20       1
# ...     ...     ...
# 2539     31      12
# 2540     30      12
# 2541      8       4
# 2542     23      12
# 2543     27       7
#
#       syear  emonth  \
# 0      1945     1.0
# 1      1953     1.0
# 2      1961    11.0
# 3      1963     1.0
# 4      1969     8.0
# ...     ...     ...
# 2539   1982    12.0
# 2540   1985     4.0
# 2541   1988    12.0
# 2542   1998     7.0
# 2543   2021     NaN
#
#        eyear  \
# 0     1953.0
# 1     1961.0
# 2     1963.0
# 3     1969.0
# 4     1974.0
# ...      ...
# 2539  1985.0
# 2540  1988.0
# 2541  1998.0
# 2542  2021.0
# 2543     NaN
#
#       birthyear  \
# 0        1884.0
# 1        1890.0
# 2        1917.0
# 3        1908.0
# 4        1913.0
# ...         ...
# 2539     1924.0
# 2540     1911.0
# 2541     1924.0
# 2542     1945.0
# 2543     1957.0
#
#       gender  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 2539       1
# 2540       1
# 2541       1
# 2542       1
# 2543       0
#
#       militarycareer  \
# 0                0.0
# 1                1.0
# 2                0.0
# 3                0.0
# 4                0.0
# ...              ...
# 2539             0.0
# 2540             0.0
# 2541             0.0
# 2542             0.0
# 2543             0.0
#
#       l_month  l_year
# 0        11.0  1948.0
# 1        11.0  1952.0
# 2        11.0  1960.0
# 3        11.0  1964.0
# 4        11.0  1968.0
# ...       ...     ...
# 2539      2.0  1985.0
# 2540      NaN     NaN
# 2541      NaN     NaN
# 2542      7.0  1998.0
# 2543      4.0  2021.0
#
# [2544 rows x 14 columns]

# %% [markdown]
# ##### Analysis of dataframe regarding NaN values and duplicates

# %%
for col in dfLeaderList.columns:
    pct_missing = round(np.mean(dfLeaderList[col].isnull()),2)
    print('{}-{}%'.format(col, pct_missing))
# Out:
# stateabb-0.0%
# ccode-0.0%
# leadid-0.0%
# leader-0.0%
# sdate-0.0%
# smonth-0.0%
# syear-0.0%
# emonth-0.08%
# eyear-0.08%
# birthyear-0.0%
# gender-0.0%
# militarycareer-0.0%
# l_month-0.51%
# l_year-0.51%

# %% [markdown]
# ##### Converting NaN values to 0

# %%
dfLeaderList = dfLeaderList.fillna(0)

# %% [markdown]
# ##### Look for example data based on string:

# %%
dfLeaderList[dfLeaderList['leader'].str.match('Macron')]
# Out:
#     stateabb  ccode  \
# 636      FRN    220
#
#        leadid  leader  \
# 636  se-220-2  Macron
#
#      sdate  smonth  \
# 636     14       5
#
#      syear  emonth  \
# 636   2017     0.0
#
#      eyear  birthyear  \
# 636    0.0     1977.0
#
#      gender  \
# 636       1
#
#      militarycareer  \
# 636             0.0
#
#      l_month  l_year
# 636      5.0  2017.0

# %%
dfLeaderList[dfLeaderList['leader'].str.match('Bi')]
# Out:
#      stateabb  ccode  \
# 13        USA      2
# 490       ARG    160
# 571       NTH    210
# 612       FRN    220
# 755       POL    290
# 783       AUS    305
# 1276      LAT    367
# 1351      SWD    380
# 1548      SIE    451
# 1575      CAO    471
# 1629      UGA    500
# 1699      MAW    553
# 1790      ALG    615
# 2211      NEP    790
# 2391      NEW    920
#
#          leadid  \
# 13      ctb-2-1
# 490   A2.9-2629
# 571   A2.9-3037
# 612   A2.9-3553
# 755   A2.9-4414
# 783   ctb-305-2
# 1276  A2.9-5650
# 1351  A2.9-5932
# 1548  A2.9-6529
# 1575  A2.9-6586
# 1629  A2.9-6721
# 1699  A2.9-6898
# 1790  A2.9-7153
# 2211  A2.9-8518
# 2391   se-920-1
#
#                   leader  \
# 13                 Biden
# 490              Bignone
# 571           Biesheuvel
# 612              Bidault
# 755               Bierut
# 783             Bierlein
# 1276             Birkavs
# 1351               Bildt
# 1548                 Bio
# 1575                Biya
# 1629             Binaisa
# 1699  Bingu wa Mutharika
# 1790               Bitat
# 2211            Birendra
# 2391        Bill English
#
#       sdate  smonth  \
# 13       20       1
# 490       1       7
# 571       6       7
# 612      28      10
# 755      31      12
# 783       3       6
# 1276      3       8
# 1351     30      10
# 1548     17       1
# 1575      6      11
# 1629     20       6
# 1699     24       5
# 1790     27      12
# 2211     31       1
# 2391     12      12
#
#       syear  emonth  \
# 13     2021     0.0
# 490    1982    12.0
# 571    1971     5.0
# 612    1949     6.0
# 755    1944     3.0
# 783    2019     1.0
# 1276   1993     9.0
# 1351   1991    10.0
# 1548   1996     3.0
# 1575   1982     0.0
# 1629   1979     5.0
# 1699   2004     4.0
# 1790   1978     2.0
# 2211   1972    11.0
# 2391   2016    10.0
#
#        eyear  \
# 13       0.0
# 490   1983.0
# 571   1973.0
# 612   1950.0
# 755   1956.0
# 783   2020.0
# 1276  1994.0
# 1351  1994.0
# 1548  1996.0
# 1575     0.0
# 1629  1980.0
# 1699  2012.0
# 1790  1979.0
# 2211  1990.0
# 2391  2017.0
#
#       birthyear  \
# 13       1942.0
# 490      1928.0
# 571      1920.0
# 612      1899.0
# 755      1892.0
# 783      1949.0
# 1276     1942.0
# 1351     1949.0
# 1548     1964.0
# 1575     1933.0
# 1629     1919.0
# 1699     1934.0
# 1790     1925.0
# 2211     1946.0
# 2391     1961.0
#
#       gender  \
# 13         1
# 490        1
# 571        1
# 612        1
# 755        1
# 783        0
# 1276       1
# 1351       1
# 1548       1
# 1575       1
# 1629       1
# 1699       1
# 1790       1
# 2211       1
# 2391       1
#
#       militarycareer  \
# 13               0.0
# 490              1.0
# 571              0.0
# 612              0.0
# 755              0.0
# 783              0.0
# 1276             0.0
# 1351             0.0
# 1548             0.0
# 1575             0.0
# 1629             0.0
# 1699             0.0
# 1790             0.0
# 2211             0.0
# 2391             0.0
#
#       l_month  l_year
# 13       11.0  2021.0
# 490       0.0     0.0
# 571       4.0  1971.0
# 612       0.0     0.0
# 755       1.0  1947.0
# 783       0.0     0.0
# 1276      6.0  1993.0
# 1351      9.0  1991.0
# 1548      0.0     0.0
# 1575      1.0  1984.0
# 1629      0.0     0.0
# 1699      5.0  2004.0
# 1790      0.0     0.0
# 2211      0.0     0.0
# 2391      0.0     0.0

# %%
dfLeaderList[dfLeaderList['leader'].str.match('Du')]
# Out:
#      stateabb  ccode  \
# 47        HAI     41
# 48        HAI     41
# 233       SAL     92
# 235       SAL     92
# 359       ECU    130
# 390       BRA    140
# 579       BEL    211
# 603       LUX    212
# 767       POL    290
# 802       CZE    315
# 1037      MNG    341
# 1039      MNG    341
# 1041      MNG    341
# 1042      MNG    341
#
#          leadid  \
# 47     A2.9-304
# 48     A2.9-307
# 233    A2.9-961
# 235    A2.9-967
# 359   A2.9-1789
# 390   A2.9-1996
# 579   A2.9-3160
# 603   A2.9-3244
# 767    cb-290-1
# 802   A2.9-4594
# 1037   cb-mng-1
# 1039   cb-mng-3
# 1041   cb-mng-5
# 1042   cb-mng-6
#
#                   leader  \
# 47    Duvalier, Francois
# 48       Duvalier, Jean-
# 233               Duarte
# 235               Duarte
# 359         Duran Ballen
# 390                Dutra
# 579           Duvieusart
# 603               Dupong
# 767                 Duda
# 802               Dubcek
# 1037           Dukanovic
# 1039           Dukanovic
# 1041           Dukanovic
# 1042      Dusko Markovic
#
#       sdate  smonth  \
# 47       15      10
# 48       22       4
# 233      13      12
# 235       1       6
# 359      10       8
# 390      31       1
# 579       8       6
# 603       9       5
# 767       6       8
# 802       5       1
# 1037      3       6
# 1039     29       2
# 1041      4      12
# 1042     28      11
#
#       syear  emonth  \
# 47     1957     4.0
# 48     1971     2.0
# 233    1980     5.0
# 235    1984     6.0
# 359    1992     8.0
# 390    1946     1.0
# 579    1950     8.0
# 603    1945    12.0
# 767    2015     0.0
# 802    1968     8.0
# 1037   2006    11.0
# 1039   2008    12.0
# 1041   2012    11.0
# 1042   2016    12.0
#
#        eyear  \
# 47    1971.0
# 48    1986.0
# 233   1982.0
# 235   1989.0
# 359   1996.0
# 390   1951.0
# 579   1950.0
# 603   1953.0
# 767      0.0
# 802   1968.0
# 1037  2006.0
# 1039  2010.0
# 1041  2016.0
# 1042  2020.0
#
#       birthyear  \
# 47       1907.0
# 48       1951.0
# 233      1925.0
# 235      1925.0
# 359      1921.0
# 390      1885.0
# 579      1900.0
# 603      1885.0
# 767      1972.0
# 802      1921.0
# 1037     1962.0
# 1039     1962.0
# 1041     1962.0
# 1042     1958.0
#
#       gender  \
# 47         1
# 48         1
# 233        1
# 235        1
# 359        1
# 390        1
# 579        1
# 603        1
# 767        1
# 802        1
# 1037       1
# 1039       1
# 1041       1
# 1042       1
#
#       militarycareer  \
# 47               0.0
# 48               0.0
# 233              0.0
# 235              0.0
# 359              0.0
# 390              1.0
# 579              0.0
# 603              0.0
# 767              0.0
# 802              0.0
# 1037             0.0
# 1039             0.0
# 1041             0.0
# 1042             0.0
#
#       l_month  l_year
# 47        9.0  1957.0
# 48        1.0  1971.0
# 233       0.0     0.0
# 235       5.0  1984.0
# 359       7.0  1992.0
# 390      12.0  1945.0
# 579       6.0  1950.0
# 603       5.0  1937.0
# 767       5.0  2015.0
# 802       0.0     0.0
# 1037      9.0  2006.0
# 1039      9.0  2006.0
# 1041     10.0  2012.0
# 1042     10.0  2016.0

# %% [markdown]
# ##### Changing data types of columns

# %%
dfLeaderList.dtypes
# Out:
# stateabb           object
# ccode               int64
# leadid             object
# leader             object
# sdate               int64
# smonth              int64
# syear               int64
# emonth            float64
# eyear             float64
# birthyear         float64
# gender              int64
# militarycareer    float64
# l_month           float64
# l_year            float64
# dtype: object

# %%
dfLeaderList = dfLeaderList.astype({"emonth":'int',
                                    "eyear":'int',
                                    "birthyear":'int',
                                    "gender":'int',
                                   "militarycareer":'int',
                                   "l_month":'int',
                                   "l_year":'int'})

# %%
dfLeaderList.dtypes
# Out:
# stateabb          object
# ccode              int64
# leadid            object
# leader            object
# sdate              int64
# smonth             int64
# syear              int64
# emonth             int32
# eyear              int32
# birthyear          int32
# gender             int32
# militarycareer     int32
# l_month            int32
# l_year             int32
# dtype: object

# %%
dfLeaderList
# Out:
#      stateabb  ccode  \
# 0         USA      2
# 1         USA      2
# 2         USA      2
# 3         USA      2
# 4         USA      2
# ...       ...    ...
# 2539      WSM    990
# 2540      WSM    990
# 2541      WSM    990
# 2542      WSM    990
# 2543      WSM    990
#
#         leadid  \
# 0      A2.9-46
# 1      A2.9-49
# 2      A2.9-52
# 3      A2.9-55
# 4      A2.9-58
# ...        ...
# 2539  kb-800-8
# 2540  kb-800-9
# 2541  kb-810-1
# 2542  kb-810-2
# 2543  mf-990-1
#
#                             leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       sdate  smonth  \
# 0        12       4
# 1        20       1
# 2        20       1
# 3        22      11
# 4        20       1
# ...     ...     ...
# 2539     31      12
# 2540     30      12
# 2541      8       4
# 2542     23      12
# 2543     27       7
#
#       syear  emonth  \
# 0      1945       1
# 1      1953       1
# 2      1961      11
# 3      1963       1
# 4      1969       8
# ...     ...     ...
# 2539   1982      12
# 2540   1985       4
# 2541   1988      12
# 2542   1998       7
# 2543   2021       0
#
#       eyear  birthyear  \
# 0      1953       1884
# 1      1961       1890
# 2      1963       1917
# 3      1969       1908
# 4      1974       1913
# ...     ...        ...
# 2539   1985       1924
# 2540   1988       1911
# 2541   1998       1924
# 2542   2021       1945
# 2543      0       1957
#
#       gender  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 2539       1
# 2540       1
# 2541       1
# 2542       1
# 2543       0
#
#       militarycareer  \
# 0                  0
# 1                  1
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2539               0
# 2540               0
# 2541               0
# 2542               0
# 2543               0
#
#       l_month  l_year
# 0          11    1948
# 1          11    1952
# 2          11    1960
# 3          11    1964
# 4          11    1968
# ...       ...     ...
# 2539        2    1985
# 2540        0       0
# 2541        0       0
# 2542        7    1998
# 2543        4    2021
#
# [2544 rows x 14 columns]

# %% [markdown]
# ##### Changing the name of columns

# %%
dfLeaderList.rename(columns = {'stateabb':'State Abbreviation',
                               'leadid':'Lead Id',
                               'leader':'Leader',
                               'sdate':'Day of Start of Term of Office',
                               'smonth':'Month of Start of Term of Office',
                               'syear':'Year of Start of Term of Office',
                               'emonth':'Month of End of Term of Office',
                               'eyear':'Year of End of Term of Office',
                               'birthyear':'Year of birth',
                               'gender':'Gender',
                               'militarycareer':'Military Career',
                               'l_month':'Month of Election or Re-election Result',
                               'l_year':'Year of Election or Re-election Result'
                                }, inplace=True)

# %%
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 2539       1
# 2540       1
# 2541       1
# 2542       1
# 2543       0
#
#       Military Career  \
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 2539                0
# 2540                0
# 2541                0
# 2542                0
# 2543                0
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
# [2544 rows x 14 columns]

# %% [markdown]
# ##### Changing data type of columns and values

# %%
dfLeaderList['Military Career'] = np.where(dfLeaderList['Military Career']== 1, True, False)

# %%
def Gender(val):
    if val == 1:
        return 'Male'
    if val == 0:
        return 'Female'

# %%
dfLeaderList['Gender'] = dfLeaderList['Gender'].apply(Gender)

# %%
dfLeaderListFemale = dfLeaderList[dfLeaderList['Gender'].isin(["Female"])]

# %%
dfLeaderListFemale
# Out:
#      State Abbreviation  \
# 22                  CAN
# 30                  BHM
# 53                  HAI
# 94                  JAM
# 97                  JAM
# ...                 ...
# 2388                NEW
# 2389                NEW
# 2392                NEW
# 2511                MSI
# 2543                WSM
#
#       ccode    Lead Id  \
# 22       20   A2.9-145
# 30       31     A3.0-3
# 53       41   A2.9-325
# 94       51     A3.0-8
# 97       51    cb-51-1
# ...     ...        ...
# 2388    920  A2.9-9064
# 2389    920  A2.9-9067
# 2392    920   se-920-2
# 2511    983  cb-983-10
# 2543    990   mf-990-1
#
#                     Leader  \
# 22            Kim Campbell
# 30                   Pratt
# 53         Pascal-Troillet
# 94          Simpson Miller
# 97          Simpson Miller
# ...                    ...
# 2388               Shipley
# 2389                 Clark
# 2392        Jacinda Ardern
# 2511           Hilda Heine
# 2543  Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 22                                25
# 30                                 4
# 53                                13
# 94                                30
# 97                                 5
# ...                              ...
# 2388                               8
# 2389                              10
# 2392                              26
# 2511                              28
# 2543                              27
#
#       Month of Start of Term of Office  \
# 22                                   6
# 30                                   5
# 53                                   3
# 94                                   3
# 97                                   1
# ...                                ...
# 2388                                12
# 2389                                12
# 2392                                10
# 2511                                 1
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 22                               1993
# 30                               2005
# 53                               1990
# 94                               2006
# 97                               2012
# ...                               ...
# 2388                             1997
# 2389                             1999
# 2392                             2017
# 2511                             2016
# 2543                             2021
#
#       Month of End of Term of Office  \
# 22                                11
# 30                                 6
# 53                                 2
# 94                                 9
# 97                                 3
# ...                              ...
# 2388                              12
# 2389                              11
# 2392                               0
# 2511                               1
# 2543                               0
#
#       Year of End of Term of Office  \
# 22                             1993
# 30                             2005
# 53                             1991
# 94                             2007
# 97                             2016
# ...                             ...
# 2388                           1999
# 2389                           2008
# 2392                              0
# 2511                           2020
# 2543                              0
#
#       Year of birth  \
# 22             1947
# 30             1945
# 53             1943
# 94             1945
# 97             1945
# ...             ...
# 2388           1952
# 2389           1950
# 2392           1980
# 2511           1951
# 2543           1957
#
#       Gender  \
# 22    Female
# 30    Female
# 53    Female
# 94    Female
# 97    Female
# ...      ...
# 2388  Female
# 2389  Female
# 2392  Female
# 2511  Female
# 2543  Female
#
#       Military Career  \
# 22              False
# 30              False
# 53              False
# 94              False
# 97              False
# ...               ...
# 2388            False
# 2389            False
# 2392            False
# 2511            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 22                                          0
# 30                                          0
# 53                                          0
# 94                                          0
# 97                                         12
# ...                                       ...
# 2388                                        0
# 2389                                       11
# 2392                                        9
# 2511                                        0
# 2543                                        4
#
#       Year of Election or Re-election Result
# 22                                         0
# 30                                         0
# 53                                         0
# 94                                         0
# 97                                      2011
# ...                                      ...
# 2388                                       0
# 2389                                    1999
# 2392                                    2017
# 2511                                       0
# 2543                                    2021
#
# [96 rows x 14 columns]

# %%
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
# [2544 rows x 14 columns]

# %% [markdown]
# ##### Creating date from columns

# %%
dfLeaderList.rename(columns = {'Year of Start of Term of Office':'year',
                                       'Month of Start of Term of Office':'month',
                                       'Day of Start of Term of Office':'day'}, inplace=True)
dfLeaderList['Date of Term Of Office'] = pd.to_datetime(dfLeaderList[['year',
                                                                     'month',
                                                                     'day']],
                                                          errors='coerce')

# %%
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       day  month  year  \
# 0      12      4  1945
# 1      20      1  1953
# 2      20      1  1961
# 3      22     11  1963
# 4      20      1  1969
# ...   ...    ...   ...
# 2539   31     12  1982
# 2540   30     12  1985
# 2541    8      4  1988
# 2542   23     12  1998
# 2543   27      7  2021
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result  \
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
#      Date of Term Of Office
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
# [2544 rows x 15 columns]

# %%
dfLeaderList.rename(columns = {'year':'Year of Start of Term of Office',
                                       'month':'Month of Start of Term of Office', 
                                       'day':'Day of Start of Term of Office'},
                                        inplace=True)

# %%
seventhcolumns = dfLeaderList.pop('Date of Term Of Office')
dfLeaderList.insert(7,'Date of Term Of Office',seventhcolumns)

# %%
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#      Date of Term Of Office  \
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
# [2544 rows x 15 columns]

# %%
dfLeaderList['Day'] = 1
dfLeaderList.rename(columns = {'Year of End of Term of Office':'year',
                                       'Month of End of Term of Office':'month',
                                       'Day':'day'}, inplace=True)
dfLeaderList['Date of End of Term of Office'] = pd.to_datetime(dfLeaderList[['year',
                                                                     'month',
                                                                     'day']],
                                                          errors='coerce')

# %%
dfLeaderList.rename(columns = {'year':'Year of End of Term of Office',
                               'month':'Month of End of Term of Office'}, 
                                        inplace=True)

tenthcolumns = dfLeaderList.pop('Date of End of Term of Office')
dfLeaderList.insert(10,'Date of End of Term of Office',tenthcolumns)
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#      Date of Term Of Office  \
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#      Date of End of Term of Office  \
# 0                       1953-01-01
# 1                       1961-01-01
# 2                       1963-11-01
# 3                       1969-01-01
# 4                       1974-08-01
# ...                            ...
# 2539                    1985-12-01
# 2540                    1988-04-01
# 2541                    1998-12-01
# 2542                    2021-07-01
# 2543                           NaT
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result  \
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
#       day
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ...   ...
# 2539    1
# 2540    1
# 2541    1
# 2542    1
# 2543    1
#
# [2544 rows x 17 columns]

# %%
dfLeaderList.rename(columns = {'Year of Election or Re-election Result':'year',
                                       'Month of Election or Re-election Result':'month',
                                       'Day':'day'}, inplace=True)
dfLeaderList['Date of Election or Re-election Result'] = pd.to_datetime(dfLeaderList[['year',
                                                                     'month',
                                                                     'day']],
                                                          errors='coerce')
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#      Date of Term Of Office  \
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#      Date of End of Term of Office  \
# 0                       1953-01-01
# 1                       1961-01-01
# 2                       1963-11-01
# 3                       1969-01-01
# 4                       1974-08-01
# ...                            ...
# 2539                    1985-12-01
# 2540                    1988-04-01
# 2541                    1998-12-01
# 2542                    2021-07-01
# 2543                           NaT
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       month  year  day  \
# 0        11  1948    1
# 1        11  1952    1
# 2        11  1960    1
# 3        11  1964    1
# 4        11  1968    1
# ...     ...   ...  ...
# 2539      2  1985    1
# 2540      0     0    1
# 2541      0     0    1
# 2542      7  1998    1
# 2543      4  2021    1
#
#      Date of Election or Re-election Result
# 0                                1948-11-01
# 1                                1952-11-01
# 2                                1960-11-01
# 3                                1964-11-01
# 4                                1968-11-01
# ...                                     ...
# 2539                             1985-02-01
# 2540                                    NaT
# 2541                                    NaT
# 2542                             1998-07-01
# 2543                             2021-04-01
#
# [2544 rows x 18 columns]

# %%
dfLeaderList.rename(columns = {'year':'Year of Election or Re-election Result',
                               'month':'Month of Election or Re-election Result'}, 
                                        inplace=True)

# %%
dfLeaderList.drop(['day'], axis=1, inplace=True)

# %%
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#      Date of Term Of Office  \
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#      Date of End of Term of Office  \
# 0                       1953-01-01
# 1                       1961-01-01
# 2                       1963-11-01
# 3                       1969-01-01
# 4                       1974-08-01
# ...                            ...
# 2539                    1985-12-01
# 2540                    1988-04-01
# 2541                    1998-12-01
# 2542                    2021-07-01
# 2543                           NaT
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result  \
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
#      Date of Election or Re-election Result
# 0                                1948-11-01
# 1                                1952-11-01
# 2                                1960-11-01
# 3                                1964-11-01
# 4                                1968-11-01
# ...                                     ...
# 2539                             1985-02-01
# 2540                                    NaT
# 2541                                    NaT
# 2542                             1998-07-01
# 2543                             2021-04-01
#
# [2544 rows x 17 columns]

# %% [markdown]
# ##### General information after cleaning

# %%
dfLeaderList.info(), dfLeaderList.size, dfLeaderList.shape, dfLeaderList.dtypes.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   State Abbreviation                       2544 non-null   object
#  1   ccode                                    2544 non-null   int64
#  2   Lead Id                                  2544 non-null   object
#  3   Leader                                   2544 non-null   object
#  4   Day of Start of Term of Office           2544 non-null   int64
#  5   Month of Start of Term of Office         2544 non-null   int64
#  6   Year of Start of Term of Office          2544 non-null   int64
#  7   Date of Term Of Office                   2544 non-null   datetime64[ns]
#  8   Month of End of Term of Office           2544 non-null   int32
#  9   Year of End of Term of Office            2544 non-null   int32
#  10  Date of End of Term of Office            2350 non-null   datetime64[ns]
#  11  Year of birth                            2544 non-null   int32
#  12  Gender                                   2399 non-null   object
#  13  Military Career                          2544 non-null   bool
#  14  Month of Election or Re-election Result  2544 non-null   int32
#  15  Year of Election or Re-election Result   2544 non-null   int32
#  16  Date of Election or Re-election Result   1258 non-null   datetime64[ns]
# dtypes: bool(1), datetime64[ns](3), int32(5), int64(4), object(4)
# memory usage: 270.9+ KB
# (None,
#  43248,
#  (2544, 17),
#  int32             5
#  object            4
#  int64             4
#  datetime64[ns]    3
#  bool              1
#  dtype: int64)

# %% [markdown]
# ##### Exploratory Data Analysis: dfGovernment

# %%
dfGovernment
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#           gwf_country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#          gwf_casename  \
# 0         USA9/1/1787
# 1         Canada11668
# 2    Bahamas6/30/1973
# 3           Cuba12298
# 4           Cuba19063
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     gwf_startdate  \
# 0        3/4/1789
# 1      12-11-1931
# 2       6/30/1973
# 3      10-10-1940
# 4      03-10-1952
# ..            ...
# 624     1/31/1968
# 625    10-01-1979
# 626    01-01-1981
# 627    05-11-1979
# 628    12-01-1961
#
#     gwf_enddate  \
# 0    12/31/2020
# 1    12/31/2020
# 2    12/31/2020
# 3    03-10-1952
# 4    01-01-1959
# ..          ...
# 624  12/31/2020
# 625  12/31/2020
# 626  12/31/2020
# 627  12/31/2020
# 628  12/31/2020
#
#     gwf_regimetype
# 0     presidential
# 1    parliamentary
# 2    parliamentary
# 3     presidential
# 4         personal
# ..             ...
# 624  parliamentary
# 625   presidential
# 626   presidential
# 627  parliamentary
# 628  parliamentary
#
# [629 rows x 6 columns]

# %% [markdown]
# ##### Looking for NaN Values

# %%
dfGovernment.isnull().sum()
# Out:
# ccode             0
# gwf_country       0
# gwf_casename      0
# gwf_startdate     0
# gwf_enddate       0
# gwf_regimetype    0
# dtype: int64

# %% [markdown]
# ##### Looking for duplicate rows

# %%
dfGovernment.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Changing data type

# %%
print(dfGovernment['gwf_startdate'].unique())
# Out:
# ['3/4/1789' '12-11-1931' '6/30/1973' '10-10-1940' '03-10-1952'
#  '01-01-1959' '8/16/1946' '05-10-1950' '12-12-1956' '04-02-1957'
#  '5/20/1957' '6/14/1957' '02-07-1986' '02-07-1988' '9/17/1988'
#  '03-10-1990' '02-07-1991' '9/30/1991' '10-12-1994' '01-12-1999'
#  '2/29/2004' '5/14/2006' '02-08-2016' '02-07-2017' '8/16/1930'
#  '12/29/1961' '1/19/1962' '2/27/1963' '9/26/1963' '4/24/1965' '07-01-1966'
#  '5/16/1978' '07-06-1962' '7/31/1962' '10/30/1966' '10-03-1978'
#  '01-07-1974' '3/13/1979' '10/19/1983' '10/25/1983' '12-09-1983'
#  '12-04-1984' '1/22/1979' '9/27/1979' '10-01-1981' '8/19/1983'
#  '08-02-1915' '07-02-2000' '08-01-1981' '3/14/1945' '6/27/1954'
#  '07-08-1954' '7/20/1957' '10/28/1957' '03-02-1958' '3/30/1963'
#  '05-10-1966' '03-01-1970' '3/23/1982' '08-08-1983' '1/14/1986'
#  '06-01-1993' '11-12-1995' '02-01-1933' '11/15/1954' '10/21/1956'
#  '12/21/1957' '10-03-1963' '3/28/1971' '12-04-1972' '4/22/1975'
#  '08-07-1978' '11/29/1981' '12/14/1948' '9/14/1950' '10/26/1960'
#  '1/25/1962' '10/15/1979' '05-02-1982' '06-01-1989' '01-01-1937'
#  '7/17/1979' '2/25/1990' '12/21/2020' '11-08-1949' '11/24/1949'
#  '05-10-1951' '10-01-1952' '01-03-1955' '10-01-1960' '10-11-1968'
#  '03-03-1982' '12/20/1989' '11-09-1949' '6/13/1953' '05-10-1958'
#  '11/24/1948' '1/23/1958' '12-04-2005' '4/26/1966' '10-09-1992'
#  '10/25/1975' '2/15/1980' '1/25/1988' '12/24/1990' '9/16/1991'
#  '09-01-1948' '07-11-1963' '3/29/1966' '09-01-1968' '6/22/1970'
#  '2/15/1972' '01-11-1976' '4/29/1979' '10/27/1948' '6/17/1956' '7/18/1962'
#  '06-09-1963' '10-03-1968' '5/18/1980' '04-05-1992' '11/21/2000'
#  '7/28/2001' '1/31/1946' '09-08-1961' '1/23/1963' '04-01-1964' '1/15/1985'
#  '7/21/1946' '5/16/1951' '04-09-1952' '11-04-1964' '9/26/1969' '8/21/1971'
#  '7/21/1978' '7/17/1980' '10-10-1982' '12-03-2017' '11-10-2019'
#  '10/18/2020' '06-03-1948' '05-07-1954' '05-09-1993' '01-01-1933'
#  '09-11-1973' '12/14/1989' '2/24/1946' '9/28/1951' '9/16/1955' '2/23/1958'
#  '6/28/1966' '03-11-1973' '3/24/1976' '10/30/1983' '03-01-1943'
#  '1/25/1952' '2/15/1967' '6/27/1973' '11/25/1984' '01-01-1912'
#  '01-01-1922' '1/1/1871' '01-01-1921' '10/14/1946' '10-04-1958'
#  '01-01-1911' '09-01-1921' '9/12/1848' '3/28/1939' '11-01-1975'
#  '07-01-1976' '12-01-1981' '5/25/1926' '4/25/1974' '7/23/1976'
#  '09-01-1990' '9/16/1949' '10-07-1949' '12/31/1944' '6/18/1989'
#  '04-10-1945' '10/26/1955' '2/25/1947' '3/25/1990' '3/30/2020' '2/25/1948'
#  '12-04-1989' '12-01-1992' '12-10-1945' '10/8/1600' '02-05-1962'
#  '11/29/1944' '06-01-1991' '05-03-2006' '10/17/1991' '5/25/1991'
#  '11-09-2000' '03-07-1945' '6/25/1991' '10-05-2000' '02-03-1992'
#  '12/14/1995' '1/17/2008' '6/15/2008' '11/23/1991' '09-08-1947'
#  '4/21/1967' '7/23/1974' '7/16/1960' '09-09-1944' '08-01-1990'
#  '08-03-1990' '03-06-1945' '12/22/1989' '11-07-1917' '8/21/1991'
#  '9/21/1993' '08-06-1991' '04-03-1990' '02-11-1990' '6/18/1990'
#  '8/25/1991' '7/21/1994' '05-08-2018' '03-12-1991' '01-06-1992'
#  '11/23/2003' '1/25/2004' '12/16/2018' '8/18/1991' '5/15/1992' '6/16/1993'
#  '01-01-1945' '03-01-2000' '01-01-1919' '1/1/1885' '01-01-1901'
#  '06-08-1975' '04-04-1991' '06-01-1975' '10-01-1987' '03-04-1991'
#  '08-10-1974' '11/14/1980' '05-07-1999' '2/18/2000' '9/14/2003'
#  '10-01-2005' '03-02-2009' '6/23/2014' '11/15/1963' '05-07-1971'
#  '08-03-1979' '1/18/1965' '7/22/1994' '08-08-1996' '1/18/2017' '8/22/1960'
#  '11/19/1968' '3/26/1991' '06-06-1992' '3/22/2012' '04-12-2012'
#  '09-04-2013' '8/18/2020' '7/20/1960' '04-02-2000' '12-01-1959'
#  '10/28/1963' '1/19/1964' '11/29/1965' '12/17/1967' '12-10-1969'
#  '05-07-1970' '10/26/1972' '10/28/1960' '07-10-1978' '08-03-2005'
#  '3/25/2007' '08-06-2008' '08-03-1960' '4/15/1974' '7/29/1991' '4/16/1993'
#  '1/27/1996' '04-11-1999' '12/22/1999' '02-08-2010' '04-07-2011'
#  '07-07-1960' '12/24/1999' '10/26/2000' '04-11-2011' '09-02-1958'
#  '04-03-1984' '12/23/2008' '12/21/2010' '07-05-1960' '01-03-1966'
#  '6/14/1970' '11/25/1980' '11-07-1982' '10/15/1987' '10/31/2014'
#  '12/29/2015' '01-01-1944' '04-12-1980' '09-09-1990' '7/19/1997'
#  '08-11-2003' '1/16/2006' '3/27/1961' '3/23/1967' '4/18/1968' '4/29/1992'
#  '3/29/1996' '5/25/1997' '03-10-1998' '02-06-1957' '4/27/1960' '2/24/1966'
#  '8/29/1969' '08-07-1970' '1/13/1972' '07-09-1979' '12/31/1981'
#  '01-01-1993' '3/27/1960' '04-09-1961' '1/13/1963' '8/22/1983'
#  '09-01-1960' '1/15/1966' '7/30/1975' '08-11-1979' '12/31/1983'
#  '8/26/1993' '11/17/1993' '5/31/1998' '05-01-1999' '7/17/1960' '7/31/1960'
#  '12/31/1965' '9/20/1979' '09-01-1981' '9/19/1993' '3/15/2003' '3/24/2013'
#  '03-01-2016' '07-11-1960' '4/13/1975' '3/23/1979' '06-07-1982'
#  '12-01-1990' '4/23/2021' '7/15/1960' '8/15/1963' '09-04-1968' '2/25/1991'
#  '8/31/1992' '10/14/1997' '5/30/1960' '9/14/1960' '11/24/1965' '5/17/1997'
#  '09-09-1962' '4/15/1966' '1/25/1971' '04-11-1979' '12-11-1980'
#  '7/27/1985' '1/27/1986' '11-12-1963' '12/27/2002' '10-09-1961'
#  '4/26/1964' '06-01-1962' '07-08-1966' '09-03-1987' '07-10-1993'
#  '10/21/1993' '7/25/1996' '4/30/2003' '8/26/2005' '8/20/2015' '09-01-1961'
#  '07-05-1973' '07-04-1994' '06-01-1960' '10/21/1969' '1/26/1991'
#  '9/16/2012' '5/27/1977' '1/1/1890' '09-12-1974' '5/27/1991' '4/24/1993'
#  '10-11-1975' '5/25/1975' '9/24/1964' '10/31/1991' '5/28/1996' '9/23/2011'
#  '10-11-1965' '5/29/1979' '4/18/1980' '06-06-1964' '5/17/1994' '5/31/1910'
#  '4/29/1994' '2/21/1990' '09-04-1966' '1/31/1970' '1/20/1986' '3/27/1993'
#  '8/30/1966' '08-06-1968' '5/26/1960' '5/18/1972' '6/15/1975' '02-10-1993'
#  '3/17/2009' '1/25/2014' '06-06-1975' '11/26/1989' '9/29/1995' '4/30/1999'
#  '5/26/2006' '02-12-1968' '5/29/1976' '07-01-1977' '6/18/1993'
#  '02-02-1956' '04-03-1962' '01-11-1992' '04-02-2019' '11-01-2020'
#  '4/30/1943' '7/25/1957' '1/14/2011' '01-01-2015' '1/24/1951' '09-01-1969'
#  '8/15/2011' '03-10-2021' '01-01-1955' '11/17/1958' '10/29/1964'
#  '6/14/1965' '5/25/1969' '04-06-1985' '04-12-1986' '6/30/1989'
#  '04-10-2019' '8/20/2019' '06-01-2011' '12/15/1925' '1/16/1979'
#  '10/29/1923' '5/14/1950' '10/27/1957' '5/27/1960' '10/15/1961'
#  '09-12-1980' '11-06-1983' '05-06-2019' '10/13/1932' '7/14/1958'
#  '02-08-1963' '7/17/1968' '7/16/1979' '04-07-2003' '12/31/2011'
#  '2/28/1922' '7/23/1952' '02-11-2011' '6/30/2012' '07-03-2013' '5/28/2014'
#  '4/22/2019' '12/19/1949' '11/29/1951' '2/25/1954' '2/26/1957' '2/28/1958'
#  '3/28/1962' '03-08-1963' '11/22/1943' '9/23/1976' '4/26/2005' '5/25/1946'
#  '5/14/1948' '5/20/1927' '10/30/1918' '9/26/1962' '11-05-1967' '6/13/1974'
#  '7/17/1978' '4/22/1990' '02-06-2015' '10/30/1967' '6/19/1949' '7/15/1971'
#  '07-03-1971' '07-02-1971' '12/31/1741' '10-10-1929' '7/17/1973'
#  '4/27/1978' '4/16/1992' '9/27/1996' '11/13/2001' '9/29/2014' '9/27/1990'
#  '07-09-1991' '9/30/1990' '3/24/2005' '04-07-2010' '12-01-2011'
#  '10/15/2020' '01-10-2021' '2/28/1990' '3/16/1990' '1/22/1949' '9/14/1921'
#  '06-06-1993' '09-09-1948' '8/13/1948' '5/16/1961' '6/29/1987' '8/14/1945'
#  '04-11-1951' '8/15/1947' '2/24/1952' '04-09-2008' '8/14/1947'
#  '10/27/1958' '12/20/1971' '02-09-1975' '07-05-1977' '11/16/1988'
#  '10-12-1999' '8/18/2008' '03-11-1971' '11-07-1975' '3/24/1982'
#  '12-06-1990' '01-11-2007' '01-06-2009' '01-04-1948' '9/26/1958'
#  '02-06-1960' '03-02-1962' '9/18/1988' '3/30/2011' '02-01-2021'
#  '01-01-1949' '09-07-1978' '11-09-1994' '6/26/1965' '11-11-2008'
#  '9/15/1846' '2/18/1951' '05-12-1991' '10-04-2002' '4/24/2006'
#  '11-08-1947' '9/16/1957' '10/14/1973' '3/17/1975' '10-06-1976'
#  '7/24/1988' '2/23/1991' '5/20/1992' '9/19/2006' '12/23/2007' '05-07-2014'
#  '10-09-1953' '3/18/1970' '4/17/1975' '01-07-1979' '11/24/1954'
#  '12/24/1959' '12/16/1960' '7/24/1962' '11/29/1975' '12/31/1949'
#  '12/31/1953' '11-02-1963' '7/31/1957' '05-09-2018' '07-05-1965'
#  '09-04-1967' '01-01-1947' '9/22/1972' '2/25/1986' '12/27/1949'
#  '03-11-1966' '06-07-1999' '4/20/2002' '01-01-1902' '8/16/1975'
#  '01-01-1908' '7/30/1980' '06-07-1978' '07-12-1979' '09-01-1978'
#  '09-10-1970' '4/13/1987' '5/14/1987' '06-02-1992' '5/19/1999' '5/27/2000'
#  '12-05-2006' '05-04-1970' '1/31/1968' '10-01-1979' '01-01-1981'
#  '05-11-1979' '12-01-1961']

# %%
print(dfGovernment['gwf_enddate'].unique())
# Out:
# ['12/31/2020' '03-10-1952' '01-01-1959' '05-10-1950' '12-12-1956'
#  '04-02-1957' '5/20/1957' '6/14/1957' '02-07-1986' '02-07-1988'
#  '9/17/1988' '03-10-1990' '02-07-1991' '9/30/1991' '10-12-1994'
#  '01-12-1999' '2/29/2004' '5/14/2006' '02-08-2016' '02-07-2017'
#  '12/29/1961' '1/19/1962' '2/27/1963' '9/26/1963' '4/24/1965' '07-01-1966'
#  '5/16/1978' '3/13/1979' '10/19/1983' '10/25/1983' '12-09-1983'
#  '12-04-1984' '07-02-2000' '6/27/1954' '07-08-1954' '7/20/1957'
#  '10/28/1957' '03-02-1958' '3/30/1963' '05-10-1966' '03-01-1970'
#  '3/23/1982' '08-08-1983' '1/14/1986' '06-01-1993' '11-12-1995'
#  '11/15/1954' '10/21/1956' '12/21/1957' '10-03-1963' '3/28/1971'
#  '12-04-1972' '4/22/1975' '08-07-1978' '11/29/1981' '9/14/1950'
#  '10/26/1960' '1/25/1962' '10/15/1979' '05-02-1982' '06-01-1989'
#  '7/17/1979' '2/25/1990' '12/21/2020' '12/31/2021' '05-10-1951'
#  '10-01-1952' '01-03-1955' '10-01-1960' '10-11-1968' '03-03-1982'
#  '12/20/1989' '6/13/1953' '05-10-1958' '1/23/1958' '12-04-2005'
#  '10-09-1992' '2/15/1980' '1/25/1988' '12/24/1990' '9/16/1991'
#  '07-11-1963' '3/29/1966' '09-01-1968' '6/22/1970' '2/15/1972'
#  '01-11-1976' '4/29/1979' '6/17/1956' '7/18/1962' '06-09-1963'
#  '10-03-1968' '5/18/1980' '04-05-1992' '11/21/2000' '7/28/2001'
#  '09-08-1961' '1/23/1963' '04-01-1964' '1/15/1985' '5/16/1951'
#  '04-09-1952' '11-04-1964' '9/26/1969' '8/21/1971' '7/21/1978' '7/17/1980'
#  '10-10-1982' '12-03-2017' '11-10-2019' '10/18/2020' '05-07-1954'
#  '05-09-1993' '09-11-1973' '12/14/1989' '9/28/1951' '9/16/1955'
#  '2/23/1958' '6/28/1966' '03-11-1973' '3/24/1976' '10/30/1983' '1/25/1952'
#  '2/15/1967' '6/27/1973' '11/25/1984' '10-04-1958' '11-01-1975'
#  '07-01-1976' '4/25/1974' '7/23/1976' '10-01-1990' '6/18/1989'
#  '10/26/1955' '3/25/1990' '3/30/2020' '12-04-1989' '12/31/1992'
#  '06-01-1991' '11-09-2000' '6/25/1991' '10-05-2000' '12/14/1995'
#  '6/15/2008' '4/21/1967' '7/23/1974' '08-01-1990' '12/22/1989' '8/21/1991'
#  '9/21/1993' '07-10-1994' '4/23/2018' '01-06-1992' '11/23/2003'
#  '1/25/2004' '12/16/2018' '5/15/1992' '6/16/1993' '03-01-2000'
#  '04-04-1991' '10-01-1987' '03-04-1991' '11/14/1980' '05-07-1999'
#  '2/18/2000' '9/14/2003' '10-01-2005' '03-02-2009' '6/23/2014'
#  '05-07-1971' '08-03-1979' '7/22/1994' '08-08-1996' '1/18/2017'
#  '11/19/1968' '3/26/1991' '06-06-1992' '3/22/2012' '04-12-2012'
#  '09-04-2013' '8/18/2020' '04-02-2000' '10/28/1963' '1/19/1964'
#  '11/29/1965' '12/17/1967' '12-10-1969' '05-07-1970' '10/26/1972'
#  '07-10-1978' '08-03-2005' '3/25/2007' '08-06-2008' '4/15/1974'
#  '7/29/1991' '4/16/1993' '1/27/1996' '04-11-1999' '12/22/1999'
#  '02-08-2010' '04-07-2011' '12/24/1999' '10/26/2000' '04-11-2011'
#  '04-03-1984' '12/23/2008' '12/21/2010' '01-03-1966' '6/14/1970'
#  '11/25/1980' '11-07-1982' '10/15/1987' '10/31/2014' '12/29/2015'
#  '04-12-1980' '09-09-1990' '7/19/1997' '08-11-2003' '1/16/2006'
#  '3/23/1967' '4/18/1968' '4/29/1992' '3/29/1996' '5/25/1997' '03-10-1998'
#  '4/27/1960' '2/24/1966' '8/29/1969' '08-07-1970' '1/13/1972' '07-09-1979'
#  '12/31/1981' '01-01-1993' '04-09-1961' '1/13/1963' '8/22/1983'
#  '1/15/1966' '7/30/1975' '08-11-1979' '12/31/1983' '8/26/1993'
#  '11/17/1993' '5/31/1998' '05-01-1999' '12/31/1965' '9/20/1979'
#  '09-01-1981' '9/19/1993' '3/15/2003' '3/24/2013' '03-01-2016' '4/13/1975'
#  '3/23/1979' '06-07-1982' '12-01-1990' '4/23/2021' '8/15/1963'
#  '09-04-1968' '2/25/1991' '8/31/1992' '10/14/1997' '9/14/1960'
#  '11/24/1965' '5/17/1997' '4/15/1966' '1/25/1971' '04-11-1979'
#  '12-11-1980' '7/27/1985' '1/27/1986' '12/27/2002' '4/26/1964'
#  '07-08-1966' '09-03-1987' '07-10-1993' '10/21/1993' '7/25/1996'
#  '4/30/2003' '8/26/2005' '8/20/2015' '07-05-1973' '07-04-1994'
#  '10/21/1969' '1/26/1991' '9/16/2012' '09-12-1974' '5/21/1991'
#  '10/31/1991' '5/28/1996' '9/23/2011' '5/29/1979' '4/18/1980' '5/17/1994'
#  '4/29/1994' '1/31/1970' '1/20/1986' '3/27/1993' '5/18/1972' '6/15/1975'
#  '02-10-1993' '3/17/2009' '1/25/2014' '11/26/1989' '9/29/1995' '4/30/1999'
#  '5/26/2006' '07-01-1977' '6/18/1993' '01-11-1992' '04-02-2019'
#  '11-01-2020' '7/25/1957' '1/14/2011' '01-01-2015' '09-01-1969'
#  '8/15/2011' '03-10-2021' '11/17/1958' '10/29/1964' '6/14/1965'
#  '5/25/1969' '04-06-1985' '04-12-1986' '6/30/1989' '04-10-2019'
#  '8/20/2019' '1/16/1979' '5/14/1950' '10/27/1957' '5/27/1960' '10/15/1961'
#  '09-12-1980' '11-06-1983' '05-06-2019' '7/14/1958' '02-08-1963'
#  '7/17/1968' '7/16/1979' '04-07-2003' '12/31/2011' '7/23/1952'
#  '02-11-2011' '6/30/2012' '07-03-2013' '5/28/2014' '4/22/2019'
#  '11/29/1951' '2/25/1954' '2/26/1957' '2/28/1958' '3/28/1962' '03-08-1963'
#  '9/23/1976' '4/26/2005' '9/26/1962' '11-05-1967' '6/13/1974' '7/17/1978'
#  '5/22/1990' '02-06-2015' '7/17/1973' '4/27/1978' '4/16/1992' '9/27/1996'
#  '11/13/2001' '9/29/2014' '3/24/2005' '04-07-2010' '12-01-2011'
#  '10/15/2020' '01-10-2021' '06-06-1993' '5/16/1961' '6/29/1987'
#  '04-11-1951' '04-09-2008' '10/27/1958' '12/20/1971' '02-09-1975'
#  '07-05-1977' '11/16/1988' '10-12-1999' '8/18/2008' '11-07-1975'
#  '3/24/1982' '12-06-1990' '01-11-2007' '01-06-2009' '9/26/1958'
#  '02-06-1960' '03-02-1962' '9/18/1988' '3/30/2011' '02-01-2021'
#  '09-07-1978' '11-09-1994' '11-11-2008' '2/18/1951' '05-12-1991'
#  '10-04-2002' '4/24/2006' '9/16/1957' '10/14/1973' '3/17/1975'
#  '10-06-1976' '7/24/1988' '2/23/1991' '5/20/1992' '9/19/2006' '12/23/2007'
#  '05-07-2014' '3/18/1970' '4/17/1975' '01-07-1979' '12/24/1959'
#  '12/16/1960' '7/24/1962' '11/29/1975' '11-02-1963' '4/30/1975'
#  '05-09-2018' '9/22/1972' '2/25/1986' '03-11-1966' '06-07-1999'
#  '04-12-1987' '5/14/1987' '06-02-1992' '5/19/1999' '5/27/2000'
#  '12-05-2006']

# %%
dfGovernment["gwf_startdate"] = dfGovernment["gwf_startdate"]\
                                    .apply(lambda x: x.replace("/",
                                                                "-"))
dfGovernment["gwf_enddate"] = dfGovernment["gwf_enddate"]\
                                    .apply(lambda x: x.replace("/",
                                                                "-"))

dfGovernment
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#           gwf_country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#          gwf_casename  \
# 0         USA9/1/1787
# 1         Canada11668
# 2    Bahamas6/30/1973
# 3           Cuba12298
# 4           Cuba19063
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     gwf_startdate  \
# 0        3-4-1789
# 1      12-11-1931
# 2       6-30-1973
# 3      10-10-1940
# 4      03-10-1952
# ..            ...
# 624     1-31-1968
# 625    10-01-1979
# 626    01-01-1981
# 627    05-11-1979
# 628    12-01-1961
#
#     gwf_enddate  \
# 0    12-31-2020
# 1    12-31-2020
# 2    12-31-2020
# 3    03-10-1952
# 4    01-01-1959
# ..          ...
# 624  12-31-2020
# 625  12-31-2020
# 626  12-31-2020
# 627  12-31-2020
# 628  12-31-2020
#
#     gwf_regimetype
# 0     presidential
# 1    parliamentary
# 2    parliamentary
# 3     presidential
# 4         personal
# ..             ...
# 624  parliamentary
# 625   presidential
# 626   presidential
# 627  parliamentary
# 628  parliamentary
#
# [629 rows x 6 columns]

# %%
dfGovernment["gwf_startdate"] = pd.to_datetime(dfGovernment["gwf_startdate"], errors='coerce')
dfGovernment["gwf_enddate"] = pd.to_datetime(dfGovernment["gwf_enddate"], errors='coerce')
dfGovernment["gwf_regimetype"] = dfGovernment["gwf_regimetype"].apply(lambda x: x.capitalize())
dfGovernment.drop(['gwf_casename'], axis=1, inplace=True)

# %%
dfGovernment.dtypes
# Out:
# ccode                      int64
# gwf_country               object
# gwf_startdate     datetime64[ns]
# gwf_enddate       datetime64[ns]
# gwf_regimetype            object
# dtype: object

# %%
dfGovernment
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#           gwf_country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     gwf_startdate  \
# 0      1789-03-04
# 1      1931-12-11
# 2      1973-06-30
# 3      1940-10-10
# 4      1952-03-10
# ..            ...
# 624    1968-01-31
# 625    1979-10-01
# 626    1981-01-01
# 627    1979-05-11
# 628    1961-12-01
#
#     gwf_enddate  \
# 0    2020-12-31
# 1    2020-12-31
# 2    2020-12-31
# 3    1952-03-10
# 4    1959-01-01
# ..          ...
# 624  2020-12-31
# 625  2020-12-31
# 626  2020-12-31
# 627  2020-12-31
# 628  2020-12-31
#
#     gwf_regimetype
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
# [629 rows x 5 columns]

# %% [markdown]
# ##### Filtering example data

# %%
Country = ['USA']
dfGovernment[dfGovernment['gwf_country'].isin(Country)]
# Out:
#    ccode gwf_country  \
# 0      2         USA
#
#   gwf_startdate  \
# 0    1789-03-04
#
#   gwf_enddate  \
# 0  2020-12-31
#
#   gwf_regimetype
# 0   Presidential

# %%
dfGovernment.query('gwf_country =="Poland"')
# Out:
#      ccode gwf_country  \
# 179    290      Poland
# 180    290      Poland
#
#     gwf_startdate  \
# 179    1944-12-31
# 180    1989-06-18
#
#     gwf_enddate  \
# 179  1989-06-18
# 180  2020-12-31
#
#     gwf_regimetype
# 179    Party-based
# 180   Presidential

# %%
dfGovernment.apply(lambda row: row[dfGovernment['gwf_country'].isin(['Canada','France'])])
# Out:
#      ccode gwf_country  \
# 1       20      Canada
# 164    220      France
# 165    220      France
#
#     gwf_startdate  \
# 1      1931-12-11
# 164    1946-10-14
# 165    1958-10-04
#
#     gwf_enddate  \
# 1    2020-12-31
# 164  1958-10-04
# 165  2020-12-31
#
#     gwf_regimetype
# 1    Parliamentary
# 164  Parliamentary
# 165   Presidential

# %% [markdown]
# ##### Renaming columns

# %%
dfGovernment.rename(columns = {'gwf_country':'Country',
                               'gwf_startdate':'Government Start',
                               'gwf_enddate':'Government End',
                               'gwf_regimetype':'Regime Type'
                                }, inplace=True)

# %%
dfGovernment
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#               Country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     Government Start  \
# 0         1789-03-04
# 1         1931-12-11
# 2         1973-06-30
# 3         1940-10-10
# 4         1952-03-10
# ..               ...
# 624       1968-01-31
# 625       1979-10-01
# 626       1981-01-01
# 627       1979-05-11
# 628       1961-12-01
#
#     Government End  \
# 0       2020-12-31
# 1       2020-12-31
# 2       2020-12-31
# 3       1952-03-10
# 4       1959-01-01
# ..             ...
# 624     2020-12-31
# 625     2020-12-31
# 626     2020-12-31
# 627     2020-12-31
# 628     2020-12-31
#
#        Regime Type
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
# [629 rows x 5 columns]

# %% [markdown]
# ##### General information after cleaning

# %%
dfGovernment.info(), dfGovernment.size, dfGovernment.shape, dfGovernment.dtypes.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ccode             629 non-null    int64
#  1   Country           629 non-null    object
#  2   Government Start  628 non-null    datetime64[ns]
#  3   Government End    629 non-null    datetime64[ns]
#  4   Regime Type       629 non-null    object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 24.7+ KB
# (None,
#  3145,
#  (629, 5),
#  object            2
#  datetime64[ns]    2
#  int64             1
#  dtype: int64)

# %% [markdown]
# ##### Analysis of dfGovernment

# %%
dfGovernment
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#               Country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     Government Start  \
# 0         1789-03-04
# 1         1931-12-11
# 2         1973-06-30
# 3         1940-10-10
# 4         1952-03-10
# ..               ...
# 624       1968-01-31
# 625       1979-10-01
# 626       1981-01-01
# 627       1979-05-11
# 628       1961-12-01
#
#     Government End  \
# 0       2020-12-31
# 1       2020-12-31
# 2       2020-12-31
# 3       1952-03-10
# 4       1959-01-01
# ..             ...
# 624     2020-12-31
# 625     2020-12-31
# 626     2020-12-31
# 627     2020-12-31
# 628     2020-12-31
#
#        Regime Type
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
# [629 rows x 5 columns]

# %%
dfGovernmentModified = dfGovernment

# %%
dfGovernmentModified['Current Date'] = pd.to_datetime('today')

dfGovernmentModified['Years of The Government'] = (round((dfGovernmentModified['Current Date'] -
                                                          dfGovernmentModified['Government Start'])\
                      .dt.days/ 365,0))
dfGovernmentModified
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#               Country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     Government Start  \
# 0         1789-03-04
# 1         1931-12-11
# 2         1973-06-30
# 3         1940-10-10
# 4         1952-03-10
# ..               ...
# 624       1968-01-31
# 625       1979-10-01
# 626       1981-01-01
# 627       1979-05-11
# 628       1961-12-01
#
#     Government End  \
# 0       2020-12-31
# 1       2020-12-31
# 2       2020-12-31
# 3       1952-03-10
# 4       1959-01-01
# ..             ...
# 624     2020-12-31
# 625     2020-12-31
# 626     2020-12-31
# 627     2020-12-31
# 628     2020-12-31
#
#        Regime Type  \
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
#                   Current Date  \
# 0   2023-02-04 20:44:42.193967
# 1   2023-02-04 20:44:42.193967
# 2   2023-02-04 20:44:42.193967
# 3   2023-02-04 20:44:42.193967
# 4   2023-02-04 20:44:42.193967
# ..                         ...
# 624 2023-02-04 20:44:42.193967
# 625 2023-02-04 20:44:42.193967
# 626 2023-02-04 20:44:42.193967
# 627 2023-02-04 20:44:42.193967
# 628 2023-02-04 20:44:42.193967
#
#      Years of The Government
# 0                      234.0
# 1                       91.0
# 2                       50.0
# 3                       82.0
# 4                       71.0
# ..                       ...
# 624                     55.0
# 625                     43.0
# 626                     42.0
# 627                     44.0
# 628                     61.0
#
# [629 rows x 7 columns]

# %%
dfGovernmentModified['Years of The Government'].isnull().sum()
# Out:
# 1

# %%
dfGovernmentModified = dfGovernmentModified.fillna(0)

# %%
dfGovernmentModified = dfGovernmentModified.astype({"Years of The Government":'int'})

# %%
dfGovernmentModified.dtypes
# Out:
# ccode                               int64
# Country                            object
# Government Start                   object
# Government End             datetime64[ns]
# Regime Type                        object
# Current Date               datetime64[ns]
# Years of The Government             int32
# dtype: object

# %%
dfGovernmentModified.drop(['Current Date'],axis=1, inplace=True)
dfGovernment.drop(['Current Date'],axis=1, inplace=True)

# %%
dfGovernmentModified
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#               Country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#         Government Start  \
# 0    1789-03-04 00:00:00
# 1    1931-12-11 00:00:00
# 2    1973-06-30 00:00:00
# 3    1940-10-10 00:00:00
# 4    1952-03-10 00:00:00
# ..                   ...
# 624  1968-01-31 00:00:00
# 625  1979-10-01 00:00:00
# 626  1981-01-01 00:00:00
# 627  1979-05-11 00:00:00
# 628  1961-12-01 00:00:00
#
#     Government End  \
# 0       2020-12-31
# 1       2020-12-31
# 2       2020-12-31
# 3       1952-03-10
# 4       1959-01-01
# ..             ...
# 624     2020-12-31
# 625     2020-12-31
# 626     2020-12-31
# 627     2020-12-31
# 628     2020-12-31
#
#        Regime Type  \
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
#      Years of The Government
# 0                        234
# 1                         91
# 2                         50
# 3                         82
# 4                         71
# ..                       ...
# 624                       55
# 625                       43
# 626                       42
# 627                       44
# 628                       61
#
# [629 rows x 6 columns]

# %% [markdown]
# ##### Top 25 Countries with the greatest Year of the Government

# %%
dfGovernmentModified.nlargest(25, 'Years of The Government')
# Out:
#      ccode  \
# 513    698
# 0        2
# 570    790
# 168    225
# 161    210
# 163    212
# 239    385
# 401    530
# 240    390
# 609    900
# 611    920
# 416    560
# 166    221
# 159    200
# 46      70
# 217    365
# 238    380
# 501    678
# 162    211
# 160    205
# 167    223
# 481    651
# 532    712
# 466    640
# 173    235
#
#            Country  \
# 513           Oman
# 0              USA
# 570          Nepal
# 168    Switzerland
# 161    Netherlands
# 163     Luxembourg
# 239         Norway
# 401       Ethiopia
# 240        Denmark
# 609      Australia
# 611    New Zealand
# 416   South Africa
# 166         Monaco
# 159            UKG
# 46          Mexico
# 217   Soviet Union
# 238         Sweden
# 501          Yemen
# 162        Belgium
# 160        Ireland
# 167  Liechtenstein
# 481          Egypt
# 532       Mongolia
# 466         Turkey
# 173       Portugal
#
#         Government Start  \
# 513  1741-12-31 00:00:00
# 0    1789-03-04 00:00:00
# 570  1846-09-15 00:00:00
# 168  1848-09-12 00:00:00
# 161  1871-01-01 00:00:00
# 163  1871-01-01 00:00:00
# 239  1885-01-01 00:00:00
# 401  1890-01-01 00:00:00
# 240  1901-01-01 00:00:00
# 609  1902-01-01 00:00:00
# 611  1908-01-01 00:00:00
# 416  1910-05-31 00:00:00
# 166  1911-01-01 00:00:00
# 159  1912-01-01 00:00:00
# 46   1915-08-02 00:00:00
# 217  1917-11-07 00:00:00
# 238  1919-01-01 00:00:00
# 501  1918-10-30 00:00:00
# 162  1921-01-01 00:00:00
# 160  1922-01-01 00:00:00
# 167  1921-09-01 00:00:00
# 481  1922-02-28 00:00:00
# 532  1921-09-14 00:00:00
# 466  1923-10-29 00:00:00
# 173  1926-05-25 00:00:00
#
#     Government End  \
# 513     2020-12-31
# 0       2020-12-31
# 570     1951-02-18
# 168     2020-12-31
# 161     2020-12-31
# 163     2020-12-31
# 239     2020-12-31
# 401     1974-09-12
# 240     2020-12-31
# 609     2020-12-31
# 611     2020-12-31
# 416     1994-04-29
# 166     2020-12-31
# 159     2020-12-31
# 46      2000-07-02
# 217     1991-08-21
# 238     2020-12-31
# 501     1962-09-26
# 162     2020-12-31
# 160     2020-12-31
# 167     2020-12-31
# 481     1952-07-23
# 532     1993-06-06
# 466     1950-05-14
# 173     1974-04-25
#
#        Regime Type  \
# 513       Monarchy
# 0     Presidential
# 570       Monarchy
# 168  Parliamentary
# 161  Parliamentary
# 163  Parliamentary
# 239  Parliamentary
# 401       Monarchy
# 240  Parliamentary
# 609  Parliamentary
# 611  Parliamentary
# 416      Oligarchy
# 166       Monarchy
# 159  Parliamentary
# 46     Party-based
# 217    Party-based
# 238  Parliamentary
# 501       Monarchy
# 162  Parliamentary
# 160  Parliamentary
# 167       Monarchy
# 481       Monarchy
# 532    Party-based
# 466    Party-based
# 173       Personal
#
#      Years of The Government
# 513                      281
# 0                        234
# 570                      177
# 168                      175
# 161                      152
# 163                      152
# 239                      138
# 401                      133
# 240                      122
# 609                      121
# 611                      115
# 416                      113
# 166                      112
# 159                      111
# 46                       108
# 217                      105
# 238                      104
# 501                      104
# 162                      102
# 160                      101
# 167                      101
# 481                      101
# 532                      101
# 466                       99
# 173                       97

# %%
RegimeType = dfGovernmentModified.groupby(['Regime Type'])['Regime Type'].count().to_frame()
RegimeType.rename(columns = {'Regime Type':'Quantity of Regime Types'}, inplace=True)
RegimeType = RegimeType.reset_index()

# %% [markdown]
# ##### Visualisation of Regime Type

# %%
x = RegimeType['Regime Type']
y = RegimeType['Quantity of Regime Types']

fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(x, y)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Quantity of Regime Type',
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'Lunczer93', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()
# Out:
# C:\Users\dlugo\AppData\Local\Temp\ipykernel_18596\3685942314.py:22: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
dfGovernmentCRY =dfGovernmentModified[['ccode','Country','Regime Type','Years of The Government']]
dfGovernmentCRY
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#               Country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#        Regime Type  \
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
#      Years of The Government
# 0                        234
# 1                         91
# 2                         50
# 3                         82
# 4                         71
# ..                       ...
# 624                       55
# 625                       43
# 626                       42
# 627                       44
# 628                       61
#
# [629 rows x 4 columns]

# %%
RegimeType = ['Parliamentary','Presidential','Personal']
FiltereddfGovernmentCRY = dfGovernmentCRY.apply(lambda row: row[dfGovernment['Regime Type'].isin(RegimeType)])

# %%
FiltereddfGovernmentCRY = FiltereddfGovernmentCRY.sort_values(by=['Regime Type','Years of The Government'], ascending=False)

# %%
Top10PresidentialRegime = FiltereddfGovernmentCRY.apply(lambda row: row[dfGovernment['Regime Type']\
                                              .isin(['Presidential'])])\
                                              .nlargest(10,'Years of The Government')
Top10PresidentialRegime
# Out:
#      ccode  \
# 0        2
# 143    155
# 3       40
# 154    165
# 49      90
# 236    375
# 6       41
# 123    140
# 146    160
# 602    840
#
#          Country  \
# 0            USA
# 143        Chile
# 3           Cuba
# 154      Uruguay
# 49     Guatemala
# 236      Finland
# 6          Haiti
# 123       Brazil
# 146    Argentina
# 602  Philippines
#
#       Regime Type  \
# 0    Presidential
# 143  Presidential
# 3    Presidential
# 154  Presidential
# 49   Presidential
# 236  Presidential
# 6    Presidential
# 123  Presidential
# 146  Presidential
# 602  Presidential
#
#      Years of The Government
# 0                        234
# 143                       90
# 3                         82
# 154                       80
# 49                        78
# 236                       78
# 6                         77
# 123                       77
# 146                       77
# 602                       76

# %%
Top10ParliamentaryRegime = FiltereddfGovernmentCRY.apply(lambda row: row[dfGovernment['Regime Type']\
                                              .isin(['Parliamentary'])])\
                                              .nlargest(10,'Years of The Government')
Top10ParliamentaryRegime
# Out:
#      ccode  \
# 168    225
# 161    210
# 163    212
# 239    385
# 240    390
# 609    900
# 611    920
# 159    200
# 238    380
# 162    211
#
#          Country  \
# 168  Switzerland
# 161  Netherlands
# 163   Luxembourg
# 239       Norway
# 240      Denmark
# 609    Australia
# 611  New Zealand
# 159          UKG
# 238       Sweden
# 162      Belgium
#
#        Regime Type  \
# 168  Parliamentary
# 161  Parliamentary
# 163  Parliamentary
# 239  Parliamentary
# 240  Parliamentary
# 609  Parliamentary
# 611  Parliamentary
# 159  Parliamentary
# 238  Parliamentary
# 162  Parliamentary
#
#      Years of The Government
# 168                      175
# 161                      152
# 163                      152
# 239                      138
# 240                      122
# 609                      121
# 611                      115
# 159                      111
# 238                      104
# 162                      102

# %%
Top10PersonalRegime = FiltereddfGovernmentCRY.apply(lambda row: row[dfGovernment['Regime Type']\
                                              .isin(['Personal'])])\
                                              .nlargest(10,'Years of The Government')
Top10PersonalRegime
# Out:
#      ccode  \
# 173    235
# 24      42
# 80      93
# 169    230
# 535    732
# 7       41
# 85      95
# 605    850
# 4       40
# 147    160
#
#            Country  \
# 173       Portugal
# 24   Dominican Rep
# 80       Nicaragua
# 169          Spain
# 535    Korea South
# 7            Haiti
# 85          Panama
# 605      Indonesia
# 4             Cuba
# 147      Argentina
#
#     Regime Type  \
# 173    Personal
# 24     Personal
# 80     Personal
# 169    Personal
# 535    Personal
# 7      Personal
# 85     Personal
# 605    Personal
# 4      Personal
# 147    Personal
#
#      Years of The Government
# 173                       97
# 24                        93
# 80                        86
# 169                       84
# 535                       75
# 7                         73
# 85                        73
# 605                       73
# 4                         71
# 147                       71

# %%
CombineTopRegime = pd.concat([Top10PresidentialRegime,Top10ParliamentaryRegime,Top10PersonalRegime])

# %%
CombineTopRegime
# Out:
#      ccode    Country  \
# 0        2        USA
# 143    155      Chile
# 3       40       Cuba
# 154    165    Uruguay
# 49      90  Guatemala
# ..     ...        ...
# 7       41      Haiti
# 85      95     Panama
# 605    850  Indonesia
# 4       40       Cuba
# 147    160  Argentina
#
#       Regime Type  \
# 0    Presidential
# 143  Presidential
# 3    Presidential
# 154  Presidential
# 49   Presidential
# ..            ...
# 7        Personal
# 85       Personal
# 605      Personal
# 4        Personal
# 147      Personal
#
#      Years of The Government
# 0                        234
# 143                       90
# 3                         82
# 154                       80
# 49                        78
# ..                       ...
# 7                         73
# 85                        73
# 605                       73
# 4                         71
# 147                       71
#
# [30 rows x 4 columns]

# %% [markdown]
# ##### Adding a current person in power

# %%
SelecteddfLeaderList = dfLeaderList[['State Abbreviation'
                                     ,'ccode'
                                     ,'Leader'
                                     ,'Date of Term Of Office'
                                     ,'Year of birth','Gender'
                                     ,'Military Career']]

# %%
SelecteddfLeaderList['rank'] = SelecteddfLeaderList.groupby('ccode')['Date of Term Of Office'].rank(ascending=False)
# Out:
# C:\Users\dlugo\AppData\Local\Temp\ipykernel_18596\3626852440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SelecteddfLeaderList['rank'] = SelecteddfLeaderList.groupby('ccode')['Date of Term Of Office'].rank(ascending=False)

# %%
SelecteddfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode  \
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
# ...     ...
# 2539    990
# 2540    990
# 2541    990
# 2542    990
# 2543    990
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#      Date of Term Of Office  \
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       rank
# 0     14.0
# 1     13.0
# 2     12.0
# 3     11.0
# 4     10.0
# ...    ...
# 2539   5.0
# 2540   4.0
# 2541   3.0
# 2542   2.0
# 2543   1.0
#
# [2544 rows x 8 columns]

# %% [markdown]
# ###### Verifying data

# %%
SelecteddfLeaderList.query('ccode== 2')
# Out:
#    State Abbreviation  \
# 0                 USA
# 1                 USA
# 2                 USA
# 3                 USA
# 4                 USA
# 5                 USA
# 6                 USA
# 7                 USA
# 8                 USA
# 9                 USA
# 10                USA
# 11                USA
# 12                USA
# 13                USA
#
#     ccode      Leader  \
# 0       2      Truman
# 1       2  Eisenhower
# 2       2     Kennedy
# 3       2     Johnson
# 4       2       Nixon
# 5       2        Ford
# 6       2      Carter
# 7       2      Reagan
# 8       2        Bush
# 9       2     Clinton
# 10      2   G.W. Bush
# 11      2       Obama
# 12      2       Trump
# 13      2       Biden
#
#    Date of Term Of Office  \
# 0              1945-04-12
# 1              1953-01-20
# 2              1961-01-20
# 3              1963-11-22
# 4              1969-01-20
# 5              1974-08-09
# 6              1977-01-20
# 7              1981-01-20
# 8              1989-01-20
# 9              1993-01-20
# 10             2001-01-21
# 11             2009-01-20
# 12             2017-01-20
# 13             2021-01-20
#
#     Year of birth  \
# 0            1884
# 1            1890
# 2            1917
# 3            1908
# 4            1913
# 5            1913
# 6            1924
# 7            1911
# 8            1924
# 9            1946
# 10           1946
# 11           1961
# 12           1946
# 13           1942
#
#    Gender  \
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# 5    Male
# 6    Male
# 7    Male
# 8    Male
# 9    Male
# 10   Male
# 11   Male
# 12   Male
# 13   Male
#
#     Military Career  \
# 0             False
# 1              True
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
#
#     rank
# 0   14.0
# 1   13.0
# 2   12.0
# 3   11.0
# 4   10.0
# 5    9.0
# 6    8.0
# 7    7.0
# 8    6.0
# 9    5.0
# 10   4.0
# 11   3.0
# 12   2.0
# 13   1.0

# %%
SelecteddfLeaderList[SelecteddfLeaderList['State Abbreviation'] =='POL']
# Out:
#     State Abbreviation  \
# 755                POL
# 756                POL
# 757                POL
# 758                POL
# 759                POL
# 760                POL
# 761                POL
# 762                POL
# 763                POL
# 764                POL
# 765                POL
# 766                POL
# 767                POL
#
#      ccode  \
# 755    290
# 756    290
# 757    290
# 758    290
# 759    290
# 760    290
# 761    290
# 762    290
# 763    290
# 764    290
# 765    290
# 766    290
# 767    290
#
#           Leader  \
# 755       Bierut
# 756        Ochab
# 757      Gomulka
# 758       Gierek
# 759        Kania
# 760   Jaruzelski
# 761       Walesa
# 762  Kwasniewski
# 763    Kaczynski
# 764   Komorowski
# 765     Schetyna
# 766   Komorowski
# 767         Duda
#
#     Date of Term Of Office  \
# 755             1944-12-31
# 756             1956-03-20
# 757             1956-10-21
# 758             1970-12-20
# 759             1980-09-06
# 760             1981-10-18
# 761             1990-12-22
# 762             1995-12-23
# 763             2005-12-23
# 764             2010-04-10
# 765             2010-07-08
# 766             2010-08-06
# 767             2015-08-06
#
#      Year of birth  \
# 755           1892
# 756           1906
# 757           1905
# 758           1913
# 759           1927
# 760           1923
# 761           1943
# 762           1954
# 763           1949
# 764           1952
# 765           1963
# 766           1952
# 767           1972
#
#     Gender  \
# 755   Male
# 756   Male
# 757   Male
# 758   Male
# 759   Male
# 760   Male
# 761   Male
# 762   Male
# 763   Male
# 764   Male
# 765   Male
# 766   Male
# 767   Male
#
#      Military Career  \
# 755            False
# 756            False
# 757            False
# 758            False
# 759            False
# 760             True
# 761            False
# 762            False
# 763            False
# 764            False
# 765            False
# 766            False
# 767            False
#
#      rank
# 755  13.0
# 756  12.0
# 757  11.0
# 758  10.0
# 759   9.0
# 760   8.0
# 761   7.0
# 762   6.0
# 763   5.0
# 764   4.0
# 765   3.0
# 766   2.0
# 767   1.0

# %%
SelecteddfLeaderListInPower = SelecteddfLeaderList.query('rank == 1')
SelecteddfLeaderListInPower
# Out:
#      State Abbreviation  \
# 13                  USA
# 26                  CAN
# 34                  BHM
# 38                  CUB
# 66                  HAI
# ...                 ...
# 2501                NAU
# 2512                MSI
# 2522                PAL
# 2531                FSM
# 2543                WSM
#
#       ccode  \
# 13        2
# 26       20
# 34       31
# 38       40
# 66       41
# ...     ...
# 2501    970
# 2512    983
# 2522    986
# 2531    987
# 2543    990
#
#                     Leader  \
# 13                   Biden
# 26                 Trudeau
# 34           Hubert Minnis
# 38             Raul Castro
# 66             Ariel Henry
# ...                    ...
# 2501              Aingimea
# 2512                 Kabua
# 2522   Surangel Whipps Jr.
# 2531               Panuelo
# 2543  Fiame Naomi Mata'afa
#
#      Date of Term Of Office  \
# 13               2021-01-20
# 26               2015-11-04
# 34               2017-05-11
# 38               2008-02-24
# 66               2021-07-20
# ...                     ...
# 2501             2019-08-27
# 2512             2020-01-13
# 2522             2021-01-21
# 2531             2019-05-11
# 2543             2021-07-27
#
#       Year of birth  \
# 13             1942
# 26             1971
# 34             1954
# 38             1931
# 66             1949
# ...             ...
# 2501           1972
# 2512           1951
# 2522           1969
# 2531           1964
# 2543           1957
#
#       Gender  \
# 13      Male
# 26      Male
# 34      Male
# 38      Male
# 66      Male
# ...      ...
# 2501    Male
# 2512    Male
# 2522    Male
# 2531    Male
# 2543  Female
#
#       Military Career  \
# 13              False
# 26              False
# 34              False
# 38               True
# 66              False
# ...               ...
# 2501            False
# 2512            False
# 2522            False
# 2531            False
# 2543            False
#
#       rank
# 13     1.0
# 26     1.0
# 34     1.0
# 38     1.0
# 66     1.0
# ...    ...
# 2501   1.0
# 2512   1.0
# 2522   1.0
# 2531   1.0
# 2543   1.0
#
# [200 rows x 8 columns]

# %% [markdown]
# ##### Combining dataframes

# %%
CombineTopRegime
# Out:
#      ccode    Country  \
# 0        2        USA
# 143    155      Chile
# 3       40       Cuba
# 154    165    Uruguay
# 49      90  Guatemala
# ..     ...        ...
# 7       41      Haiti
# 85      95     Panama
# 605    850  Indonesia
# 4       40       Cuba
# 147    160  Argentina
#
#       Regime Type  \
# 0    Presidential
# 143  Presidential
# 3    Presidential
# 154  Presidential
# 49   Presidential
# ..            ...
# 7        Personal
# 85       Personal
# 605      Personal
# 4        Personal
# 147      Personal
#
#      Years of The Government
# 0                        234
# 143                       90
# 3                         82
# 154                       80
# 49                        78
# ..                       ...
# 7                         73
# 85                        73
# 605                       73
# 4                         71
# 147                       71
#
# [30 rows x 4 columns]

# %%
SelecteddfLeaderListInPower
# Out:
#      State Abbreviation  \
# 13                  USA
# 26                  CAN
# 34                  BHM
# 38                  CUB
# 66                  HAI
# ...                 ...
# 2501                NAU
# 2512                MSI
# 2522                PAL
# 2531                FSM
# 2543                WSM
#
#       ccode  \
# 13        2
# 26       20
# 34       31
# 38       40
# 66       41
# ...     ...
# 2501    970
# 2512    983
# 2522    986
# 2531    987
# 2543    990
#
#                     Leader  \
# 13                   Biden
# 26                 Trudeau
# 34           Hubert Minnis
# 38             Raul Castro
# 66             Ariel Henry
# ...                    ...
# 2501              Aingimea
# 2512                 Kabua
# 2522   Surangel Whipps Jr.
# 2531               Panuelo
# 2543  Fiame Naomi Mata'afa
#
#      Date of Term Of Office  \
# 13               2021-01-20
# 26               2015-11-04
# 34               2017-05-11
# 38               2008-02-24
# 66               2021-07-20
# ...                     ...
# 2501             2019-08-27
# 2512             2020-01-13
# 2522             2021-01-21
# 2531             2019-05-11
# 2543             2021-07-27
#
#       Year of birth  \
# 13             1942
# 26             1971
# 34             1954
# 38             1931
# 66             1949
# ...             ...
# 2501           1972
# 2512           1951
# 2522           1969
# 2531           1964
# 2543           1957
#
#       Gender  \
# 13      Male
# 26      Male
# 34      Male
# 38      Male
# 66      Male
# ...      ...
# 2501    Male
# 2512    Male
# 2522    Male
# 2531    Male
# 2543  Female
#
#       Military Career  \
# 13              False
# 26              False
# 34              False
# 38               True
# 66              False
# ...               ...
# 2501            False
# 2512            False
# 2522            False
# 2531            False
# 2543            False
#
#       rank
# 13     1.0
# 26     1.0
# 34     1.0
# 38     1.0
# 66     1.0
# ...    ...
# 2501   1.0
# 2512   1.0
# 2522   1.0
# 2531   1.0
# 2543   1.0
#
# [200 rows x 8 columns]

# %%
CombinedRegimeLeaders = CombineTopRegime.merge(SelecteddfLeaderListInPower, how='left', on='ccode')
CombinedRegimeLeaders
# Out:
#     ccode    Country  \
# 0       2        USA
# 1     155      Chile
# 2      40       Cuba
# 3     165    Uruguay
# 4      90  Guatemala
# ..    ...        ...
# 25     41      Haiti
# 26     95     Panama
# 27    850  Indonesia
# 28     40       Cuba
# 29    160  Argentina
#
#      Regime Type  \
# 0   Presidential
# 1   Presidential
# 2   Presidential
# 3   Presidential
# 4   Presidential
# ..           ...
# 25      Personal
# 26      Personal
# 27      Personal
# 28      Personal
# 29      Personal
#
#     Years of The Government  \
# 0                       234
# 1                        90
# 2                        82
# 3                        80
# 4                        78
# ..                      ...
# 25                       73
# 26                       73
# 27                       73
# 28                       71
# 29                       71
#
#    State Abbreviation  \
# 0                 USA
# 1                 CHL
# 2                 CUB
# 3                 URU
# 4                 GUA
# ..                ...
# 25                HAI
# 26                PAN
# 27                INS
# 28                CUB
# 29                ARG
#
#                 Leader  \
# 0                Biden
# 1     Sebastian Pinera
# 2          Raul Castro
# 3             Luis Pou
# 4           Giammattei
# ..                 ...
# 25         Ariel Henry
# 26  Laurentino Cortizo
# 27         Joko Widodo
# 28         Raul Castro
# 29           Fernandez
#
#    Date of Term Of Office  \
# 0              2021-01-20
# 1              2018-03-11
# 2              2008-02-24
# 3              2020-03-01
# 4              2020-01-14
# ..                    ...
# 25             2021-07-20
# 26             2019-07-01
# 27             2014-10-20
# 28             2008-02-24
# 29             2019-12-10
#
#     Year of birth  \
# 0            1942
# 1            1949
# 2            1931
# 3            1973
# 4            1956
# ..            ...
# 25           1949
# 26           1953
# 27           1961
# 28           1931
# 29           1959
#
#    Gender  \
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# ..    ...
# 25   Male
# 26   Male
# 27   Male
# 28   Male
# 29   Male
#
#     Military Career  \
# 0             False
# 1             False
# 2              True
# 3             False
# 4             False
# ..              ...
# 25            False
# 26            False
# 27            False
# 28             True
# 29            False
#
#     rank
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# ..   ...
# 25   1.0
# 26   1.0
# 27   1.0
# 28   1.0
# 29   1.0
#
# [30 rows x 11 columns]

# %% [markdown]
# ##### Look for oldest and youngest ruler

# %%
CombinedRegimeLeaders['Current Year'] = datetime.datetime.now().year

# %%
CombinedRegimeLeaders['Age of Leader'] = CombinedRegimeLeaders['Current Year'] -  CombinedRegimeLeaders['Year of birth']

# %%
CombinedRegimeLeaders
# Out:
#     ccode    Country  \
# 0       2        USA
# 1     155      Chile
# 2      40       Cuba
# 3     165    Uruguay
# 4      90  Guatemala
# ..    ...        ...
# 25     41      Haiti
# 26     95     Panama
# 27    850  Indonesia
# 28     40       Cuba
# 29    160  Argentina
#
#      Regime Type  \
# 0   Presidential
# 1   Presidential
# 2   Presidential
# 3   Presidential
# 4   Presidential
# ..           ...
# 25      Personal
# 26      Personal
# 27      Personal
# 28      Personal
# 29      Personal
#
#     Years of The Government  \
# 0                       234
# 1                        90
# 2                        82
# 3                        80
# 4                        78
# ..                      ...
# 25                       73
# 26                       73
# 27                       73
# 28                       71
# 29                       71
#
#    State Abbreviation  \
# 0                 USA
# 1                 CHL
# 2                 CUB
# 3                 URU
# 4                 GUA
# ..                ...
# 25                HAI
# 26                PAN
# 27                INS
# 28                CUB
# 29                ARG
#
#                 Leader  \
# 0                Biden
# 1     Sebastian Pinera
# 2          Raul Castro
# 3             Luis Pou
# 4           Giammattei
# ..                 ...
# 25         Ariel Henry
# 26  Laurentino Cortizo
# 27         Joko Widodo
# 28         Raul Castro
# 29           Fernandez
#
#    Date of Term Of Office  \
# 0              2021-01-20
# 1              2018-03-11
# 2              2008-02-24
# 3              2020-03-01
# 4              2020-01-14
# ..                    ...
# 25             2021-07-20
# 26             2019-07-01
# 27             2014-10-20
# 28             2008-02-24
# 29             2019-12-10
#
#     Year of birth  \
# 0            1942
# 1            1949
# 2            1931
# 3            1973
# 4            1956
# ..            ...
# 25           1949
# 26           1953
# 27           1961
# 28           1931
# 29           1959
#
#    Gender  \
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# ..    ...
# 25   Male
# 26   Male
# 27   Male
# 28   Male
# 29   Male
#
#     Military Career  \
# 0             False
# 1             False
# 2              True
# 3             False
# 4             False
# ..              ...
# 25            False
# 26            False
# 27            False
# 28             True
# 29            False
#
#     rank  Current Year  \
# 0    1.0          2023
# 1    1.0          2023
# 2    1.0          2023
# 3    1.0          2023
# 4    1.0          2023
# ..   ...           ...
# 25   1.0          2023
# 26   1.0          2023
# 27   1.0          2023
# 28   1.0          2023
# 29   1.0          2023
#
#     Age of Leader
# 0              81
# 1              74
# 2              92
# 3              50
# 4              67
# ..            ...
# 25             74
# 26             70
# 27             62
# 28             92
# 29             64
#
# [30 rows x 13 columns]

# %%
AgeOfLeader = CombinedRegimeLeaders[['Country','Leader','Age of Leader']]
AgeOfLeader
# Out:
#       Country  \
# 0         USA
# 1       Chile
# 2        Cuba
# 3     Uruguay
# 4   Guatemala
# ..        ...
# 25      Haiti
# 26     Panama
# 27  Indonesia
# 28       Cuba
# 29  Argentina
#
#                 Leader  \
# 0                Biden
# 1     Sebastian Pinera
# 2          Raul Castro
# 3             Luis Pou
# 4           Giammattei
# ..                 ...
# 25         Ariel Henry
# 26  Laurentino Cortizo
# 27         Joko Widodo
# 28         Raul Castro
# 29           Fernandez
#
#     Age of Leader
# 0              81
# 1              74
# 2              92
# 3              50
# 4              67
# ..            ...
# 25             74
# 26             70
# 27             62
# 28             92
# 29             64
#
# [30 rows x 3 columns]

# %%
print(AgeOfLeader.max())
# Out:
# Country           Uruguay
# Leader           de Sousa
# Age of Leader          92
# dtype: object

# %%
print(AgeOfLeader.min())
# Out:
# Country                  Argentina
# Leader           Alexander De Croo
# Age of Leader                   38
# dtype: object

# %% [markdown]
# ##### Visualisation of Gender and Military Career

# %%
LeaderOfGender = CombinedRegimeLeaders.groupby(['Gender'])['Gender'].count().to_frame()
LeaderOfGender.rename(columns = {'Gender':'Quantity of Gender'}, inplace=True)
LeaderOfGender.reset_index(inplace=True)
LeaderOfGender
# Out:
#    Gender  \
# 0  Female
# 1    Male
#
#    Quantity of Gender
# 0                   4
# 1                  26

# %%
labels = LeaderOfGender['Gender']  
sizes = LeaderOfGender['Quantity of Gender'] 
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax1.set_title("Gender of Leaders")

plt.show()

# %%
MilitaryCareerLeaders = CombinedRegimeLeaders.groupby(['Military Career'])['Military Career'].count().to_frame()
MilitaryCareerLeaders.rename(columns = {'Military Career':'Quantity of Military Career'}, inplace=True)
MilitaryCareerLeaders.reset_index(inplace=True)
MilitaryCareerLeaders
# Out:
#    Military Career  \
# 0            False
# 1             True
#
#    Quantity of Military Career
# 0                           27
# 1                            3

# %%
labels = MilitaryCareerLeaders['Military Career']  
sizes = MilitaryCareerLeaders['Quantity of Military Career'] 
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax1.set_title("Military Career of Leaders")

plt.show()

# %% [markdown]
# ##### Summary

# %%
dfGovernment
# Out:
#      ccode  \
# 0        2
# 1       20
# 2       31
# 3       40
# 4       40
# ..     ...
# 624    970
# 625    983
# 626    986
# 627    987
# 628    990
#
#               Country  \
# 0                 USA
# 1              Canada
# 2             Bahamas
# 3                Cuba
# 4                Cuba
# ..                ...
# 624             Nauru
# 625  Marshall Islands
# 626             Palau
# 627        Micronesia
# 628             Samoa
#
#     Government Start  \
# 0         1789-03-04
# 1         1931-12-11
# 2         1973-06-30
# 3         1940-10-10
# 4         1952-03-10
# ..               ...
# 624       1968-01-31
# 625       1979-10-01
# 626       1981-01-01
# 627       1979-05-11
# 628       1961-12-01
#
#     Government End  \
# 0       2020-12-31
# 1       2020-12-31
# 2       2020-12-31
# 3       1952-03-10
# 4       1959-01-01
# ..             ...
# 624     2020-12-31
# 625     2020-12-31
# 626     2020-12-31
# 627     2020-12-31
# 628     2020-12-31
#
#        Regime Type  \
# 0     Presidential
# 1    Parliamentary
# 2    Parliamentary
# 3     Presidential
# 4         Personal
# ..             ...
# 624  Parliamentary
# 625   Presidential
# 626   Presidential
# 627  Parliamentary
# 628  Parliamentary
#
#      Years of The Government
# 0                      234.0
# 1                       91.0
# 2                       50.0
# 3                       82.0
# 4                       71.0
# ..                       ...
# 624                     55.0
# 625                     43.0
# 626                     42.0
# 627                     44.0
# 628                     61.0
#
# [629 rows x 6 columns]

# %%
dfLeaderList
# Out:
#      State Abbreviation  \
# 0                   USA
# 1                   USA
# 2                   USA
# 3                   USA
# 4                   USA
# ...                 ...
# 2539                WSM
# 2540                WSM
# 2541                WSM
# 2542                WSM
# 2543                WSM
#
#       ccode   Lead Id  \
# 0         2   A2.9-46
# 1         2   A2.9-49
# 2         2   A2.9-52
# 3         2   A2.9-55
# 4         2   A2.9-58
# ...     ...       ...
# 2539    990  kb-800-8
# 2540    990  kb-800-9
# 2541    990  kb-810-1
# 2542    990  kb-810-2
# 2543    990  mf-990-1
#
#                             Leader  \
# 0                           Truman
# 1                       Eisenhower
# 2                          Kennedy
# 3                          Johnson
# 4                            Nixon
# ...                            ...
# 2539           Tofilau Eti Alesana
# 2540                  Va'ai Kolone
# 2541           Tofilau Eti Alesana
# 2542  Tuilaepa Sailele Malielegaoi
# 2543          Fiame Naomi Mata'afa
#
#       Day of Start of Term of Office  \
# 0                                 12
# 1                                 20
# 2                                 20
# 3                                 22
# 4                                 20
# ...                              ...
# 2539                              31
# 2540                              30
# 2541                               8
# 2542                              23
# 2543                              27
#
#       Month of Start of Term of Office  \
# 0                                    4
# 1                                    1
# 2                                    1
# 3                                   11
# 4                                    1
# ...                                ...
# 2539                                12
# 2540                                12
# 2541                                 4
# 2542                                12
# 2543                                 7
#
#       Year of Start of Term of Office  \
# 0                                1945
# 1                                1953
# 2                                1961
# 3                                1963
# 4                                1969
# ...                               ...
# 2539                             1982
# 2540                             1985
# 2541                             1988
# 2542                             1998
# 2543                             2021
#
#      Date of Term Of Office  \
# 0                1945-04-12
# 1                1953-01-20
# 2                1961-01-20
# 3                1963-11-22
# 4                1969-01-20
# ...                     ...
# 2539             1982-12-31
# 2540             1985-12-30
# 2541             1988-04-08
# 2542             1998-12-23
# 2543             2021-07-27
#
#       Month of End of Term of Office  \
# 0                                  1
# 1                                  1
# 2                                 11
# 3                                  1
# 4                                  8
# ...                              ...
# 2539                              12
# 2540                               4
# 2541                              12
# 2542                               7
# 2543                               0
#
#       Year of End of Term of Office  \
# 0                              1953
# 1                              1961
# 2                              1963
# 3                              1969
# 4                              1974
# ...                             ...
# 2539                           1985
# 2540                           1988
# 2541                           1998
# 2542                           2021
# 2543                              0
#
#      Date of End of Term of Office  \
# 0                       1953-01-01
# 1                       1961-01-01
# 2                       1963-11-01
# 3                       1969-01-01
# 4                       1974-08-01
# ...                            ...
# 2539                    1985-12-01
# 2540                    1988-04-01
# 2541                    1998-12-01
# 2542                    2021-07-01
# 2543                           NaT
#
#       Year of birth  \
# 0              1884
# 1              1890
# 2              1917
# 3              1908
# 4              1913
# ...             ...
# 2539           1924
# 2540           1911
# 2541           1924
# 2542           1945
# 2543           1957
#
#       Gender  \
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 2539    Male
# 2540    Male
# 2541    Male
# 2542    Male
# 2543  Female
#
#       Military Career  \
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 2539            False
# 2540            False
# 2541            False
# 2542            False
# 2543            False
#
#       Month of Election or Re-election Result  \
# 0                                          11
# 1                                          11
# 2                                          11
# 3                                          11
# 4                                          11
# ...                                       ...
# 2539                                        2
# 2540                                        0
# 2541                                        0
# 2542                                        7
# 2543                                        4
#
#       Year of Election or Re-election Result  \
# 0                                       1948
# 1                                       1952
# 2                                       1960
# 3                                       1964
# 4                                       1968
# ...                                      ...
# 2539                                    1985
# 2540                                       0
# 2541                                       0
# 2542                                    1998
# 2543                                    2021
#
#      Date of Election or Re-election Result
# 0                                1948-11-01
# 1                                1952-11-01
# 2                                1960-11-01
# 3                                1964-11-01
# 4                                1968-11-01
# ...                                     ...
# 2539                             1985-02-01
# 2540                                    NaT
# 2541                                    NaT
# 2542                             1998-07-01
# 2543                             2021-04-01
#
# [2544 rows x 17 columns]

# %%
dfResultElectionList
# Out:
#       ccode  \
# 0       700
# 1       700
# 2       700
# 3       700
# 4       700
# ...     ...
# 4363    552
# 4364    552
# 4365    552
# 4366    552
# 4367    552
#
#       Election Number  \
# 0                   1
# 1                   1
# 2                   2
# 3                   3
# 4                   3
# ...               ...
# 4363               12
# 4364               13
# 4365               13
# 4366               14
# 4367               15
#
#           Country  \
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 4363     Zimbabwe
# 4364     Zimbabwe
# 4365     Zimbabwe
# 4366     Zimbabwe
# 4367     Zimbabwe
#
#       Election Year  \
# 0              1987
# 1              1988
# 2              2004
# 3              2004
# 4              2004
# ...             ...
# 4363           2008
# 4364           2008
# 4365           2008
# 4366           2013
# 4367           2018
#
#       Election Month  \
# 0                 11
# 1                  4
# 2                  7
# 3                  7
# 4                 10
# ...              ...
# 4363               3
# 4364               3
# 4365               6
# 4366               7
# 4367               7
#
#      Election Day  \
# 0               1
# 1               6
# 2               1
# 3               1
# 4               9
# ...           ...
# 4363           29
# 4364           29
# 4365           27
# 4366           31
# 4367           30
#
#      Date of Election  \
# 0          1987-11-01
# 1          1988-04-06
# 2          2004-07-01
# 3          2004-07-01
# 4          2004-10-09
# ...               ...
# 4363       2008-03-29
# 4364       2008-03-29
# 4365       2008-06-27
# 4366       2013-07-31
# 4367       2018-07-30
#
#       Sequence  \
# 0            1
# 1            2
# 2            1
# 3            1
# 4            2
# ...        ...
# 4363         1
# 4364         1
# 4365         2
# 4366         1
# 4367         1
#
#                    Event  \
# 0              Announced
# 1            Vote, Early
# 2       Deadline Not Met
# 3              Announced
# 4            Vote, Early
# ...                  ...
# 4363  Vote, As Scheduled
# 4364           Announced
# 4365         Vote, Early
# 4366  Vote, As Scheduled
# 4367  Vote, As Scheduled
#
#       Election Number  \
# 0              700001
# 1              700001
# 2              700002
# 3              700003
# 4              700003
# ...               ...
# 4363           552012
# 4364           552013
# 4365           552013
# 4366           552014
# 4367           552015
#
#      Type Direct  \
# 0       L      Y
# 1       L      Y
# 2       X      Y
# 3       X      Y
# 4       X      Y
# ...   ...    ...
# 4363    X      Y
# 4364    X      Y
# 4365    X      Y
# 4366    X      Y
# 4367    X      Y
#
#      Regular  \
# 0          N
# 1          N
# 2          N
# 3          N
# 4          N
# ...      ...
# 4363       Y
# 4364       Y
# 4365       Y
# 4366       Y
# 4367       Y
#
#             Victory  \
# 0                 Y
# 1                 Y
# 2     Not Available
# 3                 Y
# 4                 Y
# ...             ...
# 4363  Not Available
# 4364              Y
# 4365              Y
# 4366              Y
# 4367              Y
#
#              Change  \
# 0                 N
# 1                 N
# 2     Not Available
# 3                 N
# 4                 N
# ...             ...
# 4363  Not Available
# 4364              N
# 4365              N
# 4366              N
# 4367              N
#
#      Runoff Election
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 4363               1
# 4364               2
# 4365               2
# 4366               N
# 4367               N
#
# [4368 rows x 16 columns]

# %%
dfResultElectionList.query("Country == 'Poland'")
# Out:
#       ccode  \
# 3182    290
# 3183    290
# 3184    290
# 3185    290
# 3186    290
# ...     ...
# 3216    290
# 3217    290
# 3218    290
# 3219    290
# 3220    290
#
#       Election Number  \
# 3182                0
# 3183                1
# 3184                1
# 3185                2
# 3186                2
# ...               ...
# 3216               26
# 3217               26
# 3218               27
# 3219               27
# 3220               28
#
#      Country  \
# 3182  Poland
# 3183  Poland
# 3184  Poland
# 3185  Poland
# 3186  Poland
# ...      ...
# 3216  Poland
# 3217  Poland
# 3218  Poland
# 3219  Poland
# 3220  Poland
#
#       Election Year  \
# 3182           1947
# 3183           1952
# 3184           1952
# 3185           1956
# 3186           1957
# ...             ...
# 3216           2020
# 3217           2020
# 3218           2020
# 3219           2020
# 3220           2025
#
#       Election Month  \
# 3182               1
# 3183               7
# 3184              10
# 3185              10
# 3186               1
# ...              ...
# 3216               5
# 3217               6
# 3218               6
# 3219               7
# 3220               6
#
#      Election Day  \
# 3182           19
# 3183           22
# 3184           26
# 3185            1
# 3186           20
# ...           ...
# 3216            6
# 3217           28
# 3218           29
# 3219           12
# 3220           28
#
#      Date of Election  \
# 3182       1947-01-19
# 3183       1952-07-22
# 3184       1952-10-26
# 3185       1956-10-01
# 3186       1957-01-20
# ...               ...
# 3216       2020-05-06
# 3217       2020-06-28
# 3218       2020-06-29
# 3219       2020-07-12
# 3220       2025-06-28
#
#       Sequence  \
# 3182         1
# 3183         1
# 3184         2
# 3185         1
# 3186         2
# ...        ...
# 3216         1
# 3217         2
# 3218         1
# 3219         2
# 3220         1
#
#                     Event  \
# 3182   Vote, As Scheduled
# 3183            Announced
# 3184          Vote, Early
# 3185            Announced
# 3186          Vote, Early
# ...                   ...
# 3216            Announced
# 3217   Vote, As Scheduled
# 3218            Announced
# 3219   Vote, As Scheduled
# 3220  Upcoming, Scheduled
#
#       Election Number  \
# 3182           290000
# 3183           290001
# 3184           290001
# 3185           290002
# 3186           290002
# ...               ...
# 3216           290026
# 3217           290026
# 3218           290027
# 3219           290027
# 3220           290028
#
#      Type Direct  \
# 3182    L      Y
# 3183    L      Y
# 3184    L      Y
# 3185    L      Y
# 3186    L      Y
# ...   ...    ...
# 3216    X      Y
# 3217    X      Y
# 3218    X      Y
# 3219    X      Y
# 3220    X      Y
#
#      Regular  \
# 3182       N
# 3183       Y
# 3184       Y
# 3185       Y
# 3186       Y
# ...      ...
# 3216       Y
# 3217       Y
# 3218       Y
# 3219       Y
# 3220       Y
#
#             Victory  \
# 3182              Y
# 3183              Y
# 3184              Y
# 3185              Y
# 3186              Y
# ...             ...
# 3216  Not Available
# 3217  Not Available
# 3218              Y
# 3219              Y
# 3220  Not Available
#
#              Change  \
# 3182              N
# 3183              N
# 3184              N
# 3185              N
# 3186              N
# ...             ...
# 3216  Not Available
# 3217  Not Available
# 3218              N
# 3219              N
# 3220  Not Available
#
#      Runoff Election
# 3182               N
# 3183               N
# 3184               N
# 3185               N
# 3186               N
# ...              ...
# 3216               1
# 3217               1
# 3218               2
# 3219               2
# 3220               N
#
# [39 rows x 16 columns]

# %%
dfLeaderList[dfLeaderList['State Abbreviation']=='POL']
# Out:
#     State Abbreviation  \
# 755                POL
# 756                POL
# 757                POL
# 758                POL
# 759                POL
# 760                POL
# 761                POL
# 762                POL
# 763                POL
# 764                POL
# 765                POL
# 766                POL
# 767                POL
#
#      ccode    Lead Id  \
# 755    290  A2.9-4414
# 756    290  A2.9-4417
# 757    290  A2.9-4420
# 758    290  A2.9-4423
# 759    290  A2.9-4426
# 760    290  A2.9-4429
# 761    290  A2.9-4432
# 762    290  A2.9-4435
# 763    290    A3.0-60
# 764    290    A3.0-61
# 765    290    A3.0-63
# 766    290    A3.0-64
# 767    290   cb-290-1
#
#           Leader  \
# 755       Bierut
# 756        Ochab
# 757      Gomulka
# 758       Gierek
# 759        Kania
# 760   Jaruzelski
# 761       Walesa
# 762  Kwasniewski
# 763    Kaczynski
# 764   Komorowski
# 765     Schetyna
# 766   Komorowski
# 767         Duda
#
#      Day of Start of Term of Office  \
# 755                              31
# 756                              20
# 757                              21
# 758                              20
# 759                               6
# 760                              18
# 761                              22
# 762                              23
# 763                              23
# 764                              10
# 765                               8
# 766                               6
# 767                               6
#
#      Month of Start of Term of Office  \
# 755                                12
# 756                                 3
# 757                                10
# 758                                12
# 759                                 9
# 760                                10
# 761                                12
# 762                                12
# 763                                12
# 764                                 4
# 765                                 7
# 766                                 8
# 767                                 8
#
#      Year of Start of Term of Office  \
# 755                             1944
# 756                             1956
# 757                             1956
# 758                             1970
# 759                             1980
# 760                             1981
# 761                             1990
# 762                             1995
# 763                             2005
# 764                             2010
# 765                             2010
# 766                             2010
# 767                             2015
#
#     Date of Term Of Office  \
# 755             1944-12-31
# 756             1956-03-20
# 757             1956-10-21
# 758             1970-12-20
# 759             1980-09-06
# 760             1981-10-18
# 761             1990-12-22
# 762             1995-12-23
# 763             2005-12-23
# 764             2010-04-10
# 765             2010-07-08
# 766             2010-08-06
# 767             2015-08-06
#
#      Month of End of Term of Office  \
# 755                               3
# 756                              10
# 757                              12
# 758                               9
# 759                              10
# 760                              12
# 761                              12
# 762                              12
# 763                               4
# 764                               7
# 765                               8
# 766                               8
# 767                               0
#
#      Year of End of Term of Office  \
# 755                           1956
# 756                           1956
# 757                           1970
# 758                           1980
# 759                           1981
# 760                           1990
# 761                           1995
# 762                           2005
# 763                           2010
# 764                           2010
# 765                           2010
# 766                           2015
# 767                              0
#
#     Date of End of Term of Office  \
# 755                    1956-03-01
# 756                    1956-10-01
# 757                    1970-12-01
# 758                    1980-09-01
# 759                    1981-10-01
# 760                    1990-12-01
# 761                    1995-12-01
# 762                    2005-12-01
# 763                    2010-04-01
# 764                    2010-07-01
# 765                    2010-08-01
# 766                    2015-08-01
# 767                           NaT
#
#      Year of birth  \
# 755           1892
# 756           1906
# 757           1905
# 758           1913
# 759           1927
# 760           1923
# 761           1943
# 762           1954
# 763           1949
# 764           1952
# 765           1963
# 766           1952
# 767           1972
#
#     Gender  \
# 755   Male
# 756   Male
# 757   Male
# 758   Male
# 759   Male
# 760   Male
# 761   Male
# 762   Male
# 763   Male
# 764   Male
# 765   Male
# 766   Male
# 767   Male
#
#      Military Career  \
# 755            False
# 756            False
# 757            False
# 758            False
# 759            False
# 760             True
# 761            False
# 762            False
# 763            False
# 764            False
# 765            False
# 766            False
# 767            False
#
#      Month of Election or Re-election Result  \
# 755                                        1
# 756                                        0
# 757                                        1
# 758                                        3
# 759                                        0
# 760                                       10
# 761                                       12
# 762                                       11
# 763                                       10
# 764                                        0
# 765                                        7
# 766                                        0
# 767                                        5
#
#      Year of Election or Re-election Result  \
# 755                                    1947
# 756                                       0
# 757                                    1957
# 758                                    1972
# 759                                       0
# 760                                    1985
# 761                                    1990
# 762                                    1995
# 763                                    2005
# 764                                       0
# 765                                    2010
# 766                                       0
# 767                                    2015
#
#     Date of Election or Re-election Result
# 755                             1947-01-01
# 756                                    NaT
# 757                             1957-01-01
# 758                             1972-03-01
# 759                                    NaT
# 760                             1985-10-01
# 761                             1990-12-01
# 762                             1995-11-01
# 763                             2005-10-01
# 764                                    NaT
# 765                             2010-07-01
# 766                                    NaT
# 767                             2015-05-01

# %% [markdown]
# #### divide dataframe on female and male , using new functions
